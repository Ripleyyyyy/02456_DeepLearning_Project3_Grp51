# %% [markdown]
# # Conformal Prediction with Cluster & k-NN Smoothing
# ### Group 51 – Technical Notebook

# %% [markdown]
# This notebook contains the full code corresponding to our 4-page report, including:
# - baseline split conformal prediction
# - feature extraction
# - cluster smoothing
# - k-NN smoothing
# - hyperparameter sweeps and plotting scripts
# - evaluation & comparison among different methods

# %% [markdown]
# ## Setup
# We import all necessary libraries for model training, evaluation, and plotting.

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt

#from conformal.data import IndexedDataset
#from conformal.train import train_model, evaluate_and_save
from functools import partial
from tqdm import tqdm
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, Subset
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## 1. Data preprocessing & Baseline classifier training
# We use CIFAR-10 with standard resizing and normalization.
# We follow the same splits as the project template:
# - 60% train
# - 20% validation
# - 20% holdout calibration set for conformal prediction.
#
# We use a pretrained ResNet-18 and fine-tune the final linear layer to output 10 classes.
# Training code is the same as in the course template.

# %%
# DO NOT RUN THIS CELL ON YOUR LOCAL COMPUTER. ONLY RUN THIS ON HPC.

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    folder = "scratch/rhti/conformal"
    num_workers = 6
    val_frac = 0.2
    holdout_frac = 0.2
    epochs = 10
    lr = 1e-3

    # Data transforms
    transform_train = transforms.Compose(
        [
            transforms.Resize(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ]
    )
    transform_test = transforms.Compose(
        [
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ]
    )

    # Datasets and loaders
    full_trainset = IndexedDataset(
        datasets.CIFAR10(
            root=folder + "/data", train=True, download=True, transform=transform_train
        )
    )
    val_size = int(val_frac * len(full_trainset))
    holdout_size = int(holdout_frac * len(full_trainset))
    train_size = len(full_trainset) - val_size - holdout_size
    trainset, valset, holdoutset = torch.utils.data.random_split(
        full_trainset, [train_size, val_size, holdout_size]
    )
    testset = IndexedDataset(
        datasets.CIFAR10(
            root=folder + "/data", train=False, download=True, transform=transform_test
        )
    )

    dataloader_settings = partial(
        torch.utils.data.DataLoader,
        batch_size=64,
        num_workers=num_workers,
        pin_memory=True if device.type == "cuda" else False,
        persistent_workers=True,
    )

    trainloader = dataloader_settings(trainset, shuffle=True, drop_last=True)
    valloader = dataloader_settings(valset, shuffle=False)
    testloader = dataloader_settings(testset, shuffle=False)
    holdoutloader = dataloader_settings(holdoutset, shuffle=False)

    # Model setup
    model = models.resnet18(pretrained=True)
    model.fc = nn.Linear(model.fc.in_features, 10)
    model = model.to(device)

    # Train the model
    model = train_model(model, trainloader, valloader, device, epochs=epochs, lr=lr)

    # Evaluation on validation set
    evaluate_and_save(model, valloader, device, folder, "val_predictions.pth")

    # Evaluation on test set
    evaluate_and_save(model, testloader, device, folder, "test_predictions.pth")

    # Save the model and predictions on the holdout set
    torch.save(model.state_dict(), folder + "/cifar10_resnet18.pth")
    evaluate_and_save(model, holdoutloader, device, folder, "holdout_predictions.pth")


if __name__ == "__main__":
    main()

# %% [markdown]
# Training was executed on DTU HPC for power efficiency (see examples/scratch folder).

# %% [markdown]
# ## 2. Baseline split conformal prediction
# We follow the standard conformal prediction procedures:
# 1. Train on train set
# 2. Compute conformity scores on holdout set
# 3. Apply threshold on validation/test predictions
#
# We evaluate:
# - Coverage (should be ≥ 1 − α)
# - Efficiency = mean |prediction set|
# - Singleton coverage (% of predictions where the set contains exactly one class)

# %%
# Load stored predictions
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    folder = "examples/scratch/rhti/conformal"

    holdout_results = torch.load(folder + "/holdout_predictions.pth")
    val_results = torch.load(folder + "/val_predictions.pth")

    cal_labels = holdout_results["labels"]
    cal_outputs = holdout_results["outputs"]
    val_outputs = val_results["outputs"]
    val_labels = val_results["labels"]
    alpha = 0.1  # 90% prediction intervals

    # Do conformal calibration
    n = len(cal_labels)
    cal_scores = 1 - cal_outputs[np.arange(n), cal_labels]
    q_level = np.ceil((n + 1) * (1 - alpha)) / n        # nonconformity score s_i
    qhat = np.quantile(cal_scores, q_level, interpolation="higher") # quantile calculation
    prediction_sets = val_outputs >= (1 - qhat)  # form prediction sets

    empirical_coverage = prediction_sets[
        np.arange(prediction_sets.shape[0]), val_labels
    ].mean()

    print(f"Empirical coverage on validation set: {empirical_coverage * 100:.2f}%")

    empirical_efficiency = prediction_sets.sum(-1).mean()

    print(f"Empirical efficiency on validation set: {empirical_efficiency:.2f}")

    singletons_idx = prediction_sets.sum(-1) == 1
    empirical_singleton = prediction_sets[
        np.arange(prediction_sets.shape[0]), val_labels
    ][singletons_idx].mean()
    print(
        f"Empirical singleton coverage on validation set: {empirical_singleton * 100:.2f}%"
    )


if __name__ == "__main__":
    main()
# Out:
# Empirical coverage on validation set: 90.16%
# Empirical efficiency on validation set: 1.14
# Empirical singleton coverage on validation set: 94.97%
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\3393329188.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   holdout_results = torch.load(folder + "/holdout_predictions.pth")
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\3393329188.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_results = torch.load(folder + "/val_predictions.pth")
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\3393329188.py:53: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   main()

# %% [markdown]
# ## 3. Feature extraction
# We extract the representation from the last hidden layer of ResNet-18
# (before the final linear classifier).
# These 512-dim embeddings are used for local smoothing (cluster / k-NN).

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    folder = "examples/scratch/rhti/conformal"

    transform_train = transforms.Compose(
        [
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize(
                (0.4914, 0.4822, 0.4465),
                (0.2023, 0.1994, 0.2010),
            ),
        ]
    )

    # Load CIFAR10 train
    base_trainset = datasets.CIFAR10(
        root=folder + "/data",
        train=True,
        download=False,
        transform=transform_train,
    )

    # Load holdout + val prediction files
    holdout_results = torch.load(folder + "/holdout_predictions.pth", weights_only=False)
    val_results = torch.load(folder + "/val_predictions.pth", weights_only=False)

    holdout_idx = holdout_results["indexes"]
    val_idx = val_results["indexes"]

    all_idx = np.concatenate([holdout_idx, val_idx], axis=0)

    subset = Subset(base_trainset, all_idx)

    loader = DataLoader(
        subset,
        batch_size=128,
        shuffle=False,
        num_workers=4,
    )

    model = models.resnet18(pretrained=False)
    model.fc = nn.Linear(model.fc.in_features, 10)
    model.load_state_dict(torch.load(folder + "/cifar10_resnet18.pth", map_location=device))
    model = model.to(device)
    model.eval()

    # Create feature extractor (remove final layer)
    feature_extractor = nn.Sequential(*list(model.children())[:-1]).to(device)
    feature_extractor.eval()

    all_features = []

    with torch.no_grad():
        for imgs, _ in loader:
            imgs = imgs.to(device)
            feats = feature_extractor(imgs)       # [B, 512, 1, 1]
            feats = feats.view(feats.size(0), -1) # [B, 512]
            all_features.append(feats.cpu())

    all_features = torch.cat(all_features, dim=0).numpy()  # [N_total, 512]

    # Split back into holdout and val features
    n_holdout = len(holdout_idx)
    holdout_features = all_features[:n_holdout]
    val_features = all_features[n_holdout:]

    np.savez(
        folder + "/holdout_features.npz",
        indexes=holdout_idx,
        features=holdout_features,
    )

    np.savez(
        folder + "/val_features.npz",
        indexes=val_idx,
        features=val_features,
    )

    print("Saved holdout_features.npz and val_features.npz")


if __name__ == "__main__":
    main()
# Out:
# C:\Users\My Lan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\My Lan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\288285375.py:60: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(folder + "/cifar10_resnet18.pth", map_location=device))
# Saved holdout_features.npz and val_features.npz

# %% [markdown]
# ## 4. Cluster smoothing
# We group the calibration features using K-Means.
# Each cluster gets its own local conformal threshold, blended with the global
# threshold using smoothing strength λ.

# %%
def evaluate_cp(cal_scores_use, val_outputs_use, val_labels_use, alpha=0.1, desc=""):
    """
    Helper: given calibration scores (1D), and validation outputs/labels,
    compute qhat, coverage, efficiency, singleton coverage.
    """
    n = len(cal_scores_use)
    q_level = np.ceil((n + 1) * (1 - alpha)) / n
    qhat = np.quantile(cal_scores_use, q_level, interpolation="higher")

    pred_sets = val_outputs_use >= (1.0 - qhat)

    coverage = pred_sets[np.arange(len(val_labels_use)), val_labels_use].mean()
    eff = pred_sets.sum(axis=-1).mean()
    singleton_idx = pred_sets.sum(axis=-1) == 1
    if singleton_idx.any():
        singleton_cov = pred_sets[
            np.arange(len(val_labels_use)), val_labels_use
        ][singleton_idx].mean()
    else:
        singleton_cov = float("nan")

    print(
        f"{desc}Coverage: {coverage*100:.2f}%, "
        f"efficiency: {eff:.2f}, "
        f"singleton cov: {singleton_cov*100:.2f}%"
    )
    return qhat, coverage, eff, singleton_cov


def main():
    folder = "examples/scratch/rhti/conformal"
    alpha = 0.1  

    holdout_results = torch.load(
        folder + "/holdout_predictions.pth", weights_only=False
    )
    val_results = torch.load(folder + "/val_predictions.pth", weights_only=False)

    cal_labels = holdout_results["labels"]          # shape [n_cal]
    cal_outputs = holdout_results["outputs"]        # shape [n_cal, 10]
    val_labels = val_results["labels"]              # shape [n_val]
    val_outputs = val_results["outputs"]            # shape [n_val, 10]

    n_cal = len(cal_labels)
    n_val = len(val_labels)

    cal_scores = 1.0 - cal_outputs[np.arange(n_cal), cal_labels]
    val_scores = 1.0 - val_outputs[np.arange(n_val), val_labels]

    print("=== Baseline CP (no clustering) ===")
    evaluate_cp(cal_scores, val_outputs, val_labels, alpha=alpha, desc="Baseline: ")

    holdout_feat = np.load(folder + "/holdout_features.npz")
    val_feat = np.load(folder + "/val_features.npz")

    cal_features = holdout_feat["features"]   # shape [n_cal, 512]
    val_features = val_feat["features"]       # shape [n_val, 512]

    num_clusters = 50
    print(f"\nFitting KMeans with {num_clusters} clusters on calibration features...")
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    cal_clusters = kmeans.fit_predict(cal_features)   
    val_clusters = kmeans.predict(val_features)      

    cluster_means = np.zeros(num_clusters, dtype=np.float64)
    global_mean = cal_scores.mean()
    for c in range(num_clusters):
        idx = (cal_clusters == c)
        if idx.any():
            cluster_means[c] = cal_scores[idx].mean()
        else:
            cluster_means[c] = global_mean

    for lam in [0.1, 0.2, 0.3]:
        # s_tilde(i) = (1 - lam) * s(i) + lam * mean_score_of_cluster(i)
        cal_scores_smooth = (1.0 - lam) * cal_scores + lam * cluster_means[cal_clusters]

        print(f"\n=== Cluster-smoothed CP with lambda = {lam} ===")
        evaluate_cp(
            cal_scores_smooth,
            val_outputs,
            val_labels,
            alpha=alpha,
            desc=f"lambda={lam}: ",
        )


if __name__ == "__main__":
    main()
# Out:
# === Baseline CP (no clustering) ===
# Baseline: Coverage: 90.16%, efficiency: 1.14, singleton cov: 94.97%
#
# Fitting KMeans with 50 clusters on calibration features...
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\1151427969.py:60: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   evaluate_cp(cal_scores, val_outputs, val_labels, alpha=alpha, desc="Baseline: ")
# === Cluster-smoothed CP with lambda = 0.1 ===
# lambda=0.1: Coverage: 89.47%, efficiency: 1.11, singleton cov: 95.11%
#
# === Cluster-smoothed CP with lambda = 0.2 ===
# lambda=0.2: Coverage: 88.63%, efficiency: 1.09, singleton cov: 95.22%
#
# === Cluster-smoothed CP with lambda = 0.3 ===
# lambda=0.3: Coverage: 88.01%, efficiency: 1.07, singleton cov: 95.42%
# C:\Users\My Lan\AppData\Local\Temp\ipykernel_4824\1151427969.py:94: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   evaluate_cp(

# %% [markdown]
# Effect of parameters:
# - K controls how fine-grained local smoothing becomes.
# - λ controls strength of local vs global calibration.

# %% [markdown]
# ## 5. k-NN smoothing
# Instead of using hard clusters, each validation/test point is smoothed using its
# k nearest calibration features in latent space.

# %%
def evaluate_cp(cal_scores_use, val_outputs_use, val_labels_use, alpha=0.1, desc=""):
    """
    Given calibration scores (1D), and validation outputs/labels,
    compute qhat, coverage, efficiency, singleton coverage.
    """
    n = len(cal_scores_use)
    q_level = np.ceil((n + 1) * (1 - alpha)) / n
    qhat = np.quantile(cal_scores_use, q_level, method="higher")

    pred_sets = val_outputs_use >= (1.0 - qhat)

    coverage = pred_sets[np.arange(len(val_labels_use)), val_labels_use].mean()
    eff = pred_sets.sum(axis=-1).mean()
    singleton_idx = pred_sets.sum(axis=-1) == 1
    if singleton_idx.any():
        singleton_cov = pred_sets[
            np.arange(len(val_labels_use)), val_labels_use
        ][singleton_idx].mean()
    else:
        singleton_cov = float("nan")

    print(
        f"{desc}Coverage: {coverage*100:.2f}%, "
        f"efficiency: {eff:.2f}, "
        f"singleton cov: {singleton_cov*100:.2f}%"
    )
    return qhat, coverage, eff, singleton_cov


def main():
    folder = "examples/scratch/rhti/conformal"
    alpha = 0.1  

    holdout_results = torch.load(
        folder + "/holdout_predictions.pth", weights_only=False
    )
    val_results = torch.load(folder + "/val_predictions.pth", weights_only=False)

    cal_labels = holdout_results["labels"]          # [n_cal]
    cal_outputs = holdout_results["outputs"]        # [n_cal, 10]
    val_labels = val_results["labels"]              # [n_val]
    val_outputs = val_results["outputs"]            # [n_val, 10]
    n_cal = len(cal_labels)
    n_val = len(val_labels)
    cal_scores = 1.0 - cal_outputs[np.arange(n_cal), cal_labels]
    val_scores = 1.0 - val_outputs[np.arange(n_val), val_labels]

    print("=== Baseline CP (no k-NN smoothing) ===")
    evaluate_cp(cal_scores, val_outputs, val_labels, alpha=alpha, desc="Baseline: ")

    holdout_feat = np.load(folder + "/holdout_features.npz")
    val_feat = np.load(folder + "/val_features.npz")

    cal_features = holdout_feat["features"]   # [n_cal, 512]
    val_features = val_feat["features"]       # [n_val, 512] 

    k = 10
    print(f"\nFitting k-NN (k={k}) on calibration features...")
    nbrs = NearestNeighbors(
        n_neighbors=k,
        algorithm="auto",
        metric="euclidean",
        n_jobs=-1,
    )
    nbrs.fit(cal_features)
    distances, indices = nbrs.kneighbors(cal_features)
    neighbor_means = cal_scores[indices].mean(axis=1)  # [n_cal]

    for lam in [0.1, 0.25, 0.5]:
        # s_tilde(i) = (1 - lam) * s(i) + lam * mean_score_of_neighbors(i)
        cal_scores_smooth = (1.0 - lam) * cal_scores + lam * neighbor_means

        print(f"\n=== k-NN-smoothed CP with lambda = {lam} ===")
        evaluate_cp(
            cal_scores_smooth,
            val_outputs,
            val_labels,
            alpha=alpha,
            desc=f"kNN lambda={lam}: ",
        )


if __name__ == "__main__":
    main()
# Out:
# === Baseline CP (no k-NN smoothing) ===
# Baseline: Coverage: 90.16%, efficiency: 1.14, singleton cov: 94.97%
#
# Fitting k-NN (k=10) on calibration features...
#
# === k-NN-smoothed CP with lambda = 0.1 ===
# kNN lambda=0.1: Coverage: 89.76%, efficiency: 1.12, singleton cov: 95.04%
#
# === k-NN-smoothed CP with lambda = 0.25 ===
# kNN lambda=0.25: Coverage: 89.31%, efficiency: 1.11, singleton cov: 95.20%
#
# === k-NN-smoothed CP with lambda = 0.5 ===
# kNN lambda=0.5: Coverage: 88.07%, efficiency: 1.07, singleton cov: 95.39%

# %% [markdown]
# ## 6. Hyperparameter sweeps
#
# We sweep the parameters:
# - Cluster smoothing: K ∈ {50, 110, 170} and λ ∈ {0.01, 0.02, 0.05, 0.1}
# - k-NN smoothing: k ∈ {2, 8, 14} and λ ∈ {0.01, 0.025, 0.05, 0.1}
#
# Plots below show the impact on coverage and efficiency.

# %% [markdown]
# ### 6.1 Clustering

# %%
folder = "code/examples/scratch/rhti/conformal"
alpha = 0.1
target_cov = 1.0 - alpha

holdout = torch.load(folder + "/holdout_predictions.pth", weights_only=False)
val = torch.load(folder + "/val_predictions.pth", weights_only=False)
test = torch.load(folder + "/test_predictions.pth", weights_only=False)
feats = np.load(folder + "/holdout_features.npz")["features"]

cal_labels = holdout["labels"]
cal_outputs = holdout["outputs"]
n_cal = len(cal_labels)
cal_scores = 1.0 - cal_outputs[np.arange(n_cal), cal_labels]

data = {
    "cal_scores": cal_scores,
    "cal_feats": feats,
    "val_labels": val["labels"],
    "val_outputs": val["outputs"],
    "test_labels": test["labels"],
    "test_outputs": test["outputs"],
}

clustering_results_global = []

def compute_qhat(cal_scores, alpha=0.1):
    n = len(cal_scores)
    q_level = np.ceil((n + 1) * (1 - alpha)) / n
    return np.quantile(cal_scores, q_level, method="higher")

def evaluate_and_return_metrics(qhat, outputs, labels, desc=""):
    pred_sets = outputs >= (1.0 - qhat)
    coverage = pred_sets[np.arange(len(labels)), labels].mean()
    eff = pred_sets.sum(axis=-1).mean()
    singleton_idx = pred_sets.sum(axis=-1) == 1
    if singleton_idx.any():
        singleton_cov = pred_sets[np.arange(len(labels)), labels][singleton_idx].mean()
    else:
        singleton_cov = np.nan
        
    result_str = f"{desc}Coverage: {coverage*100:.2f}%, Eff: {eff:.2f}, Single: {singleton_cov*100:.5f}%"
    
    return {
        "qhat": qhat,
        "coverage": coverage,
        "efficiency": eff,
        "singleton_cov": singleton_cov,
        "result_str": result_str
    }

print("Calibration Results (Baseline)")
qhat_base = compute_qhat(cal_scores, alpha)
baseline_metrics = evaluate_and_return_metrics(qhat_base, data["val_outputs"], data["val_labels"], "Baseline CAL: ")
clustering_results_global.append(("BASELINE", baseline_metrics))
print(baseline_metrics["result_str"])

Ks = list(range(20, 201, 20)) #[50, 110, 170]
lambdas = [round(0.01 + i * 0.05, 2) for i in range(20)]
 # [0.01, 0.02, 0.05, 0.1]

for K in Ks:
    print(f"CLUSTERING K={K}")
    kmeans = KMeans(n_clusters=K, random_state=0, n_init='auto')
    clusters = kmeans.fit_predict(data["cal_feats"])

    cluster_means = np.zeros(K)
    global_mean = data["cal_scores"].mean()
    for c in range(K):
        idx = clusters == c
        if idx.any():
            cluster_means[c] = data["cal_scores"][idx].mean()
        else:
            cluster_means[c] = global_mean

    for lam in lambdas:
        smooth_scores = (1.0 - lam) * data["cal_scores"] + lam * cluster_means[clusters]
        qhat = compute_qhat(smooth_scores, alpha)
        
        metrics = evaluate_and_return_metrics(qhat, data["val_outputs"], data["val_labels"], "CAL: ")
        
        config_name = f"K={K}, lambda={lam}"
        clustering_results_global.append((config_name, metrics))
        
        print(f"    lambda={lam:}: {metrics['result_str']}")
# Out:
# Calibration Results (Baseline)
# Baseline CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
# CLUSTERING K=20
#     lambda=0.01: CAL: Coverage: 90.04%, Eff: 1.13, Single: 94.98876%
#     lambda=0.06: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16256%
#     lambda=0.11: CAL: Coverage: 88.86%, Eff: 1.09, Single: 95.12894%
#     lambda=0.16: CAL: Coverage: 88.20%, Eff: 1.08, Single: 95.32552%
#     lambda=0.21: CAL: Coverage: 87.60%, Eff: 1.06, Single: 95.47043%
#     lambda=0.26: CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.62912%
#     lambda=0.31: CAL: Coverage: 86.05%, Eff: 1.02, Single: 95.65217%
#     lambda=0.36: CAL: Coverage: 85.46%, Eff: 1.00, Single: 95.67283%
#     lambda=0.41: CAL: Coverage: 84.90%, Eff: 0.99, Single: 95.82051%
#     lambda=0.46: CAL: Coverage: 84.25%, Eff: 0.97, Single: 95.91915%
#     lambda=0.51: CAL: Coverage: 83.68%, Eff: 0.96, Single: 96.05263%
#     lambda=0.56: CAL: Coverage: 83.14%, Eff: 0.95, Single: 96.04859%
#     lambda=0.61: CAL: Coverage: 82.63%, Eff: 0.94, Single: 96.06612%
#     lambda=0.66: CAL: Coverage: 82.04%, Eff: 0.93, Single: 96.08372%
#     lambda=0.71: CAL: Coverage: 81.68%, Eff: 0.92, Single: 96.14988%
#     lambda=0.76: CAL: Coverage: 81.43%, Eff: 0.91, Single: 96.12513%
#     lambda=0.81: CAL: Coverage: 81.16%, Eff: 0.91, Single: 96.11863%
#     lambda=0.86: CAL: Coverage: 80.99%, Eff: 0.91, Single: 96.13994%
#     lambda=0.91: CAL: Coverage: 80.92%, Eff: 0.91, Single: 96.17472%
#     lambda=0.96: CAL: Coverage: 80.30%, Eff: 0.89, Single: 96.35349%
# CLUSTERING K=40
#     lambda=0.01: CAL: Coverage: 90.04%, Eff: 1.13, Single: 94.98744%
#     lambda=0.06: CAL: Coverage: 89.68%, Eff: 1.12, Single: 95.03686%
#     lambda=0.11: CAL: Coverage: 89.37%, Eff: 1.11, Single: 95.17016%
#     lambda=0.16: CAL: Coverage: 88.93%, Eff: 1.10, Single: 95.15057%
#     lambda=0.21: CAL: Coverage: 88.47%, Eff: 1.08, Single: 95.28277%
#     lambda=0.26: CAL: Coverage: 88.08%, Eff: 1.07, Single: 95.37422%
#     lambda=0.31: CAL: Coverage: 87.77%, Eff: 1.06, Single: 95.43805%
#     lambda=0.36: CAL: Coverage: 87.42%, Eff: 1.05, Single: 95.52509%
#     lambda=0.41: CAL: Coverage: 86.95%, Eff: 1.04, Single: 95.61506%
#     lambda=0.46: CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.56014%
#     lambda=0.51: CAL: Coverage: 86.19%, Eff: 1.02, Single: 95.61969%
#     lambda=0.56: CAL: Coverage: 85.92%, Eff: 1.01, Single: 95.62926%
#     lambda=0.61: CAL: Coverage: 85.75%, Eff: 1.01, Single: 95.64491%
#     lambda=0.66: CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.67172%
#     lambda=0.71: CAL: Coverage: 85.41%, Eff: 1.00, Single: 95.68345%
#     lambda=0.76: CAL: Coverage: 85.27%, Eff: 1.00, Single: 95.67450%
#     lambda=0.81: CAL: Coverage: 85.09%, Eff: 0.99, Single: 95.72693%
#     lambda=0.86: CAL: Coverage: 85.13%, Eff: 0.99, Single: 95.71355%
#     lambda=0.91: CAL: Coverage: 85.19%, Eff: 1.00, Single: 95.68678%
#     lambda=0.96: CAL: Coverage: 85.12%, Eff: 0.99, Single: 95.71410%
# CLUSTERING K=60
#     lambda=0.01: CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94776%
#     lambda=0.06: CAL: Coverage: 89.79%, Eff: 1.12, Single: 95.03163%
#     lambda=0.11: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16509%
#     lambda=0.16: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%
#     lambda=0.21: CAL: Coverage: 88.84%, Eff: 1.09, Single: 95.16864%
#     lambda=0.26: CAL: Coverage: 88.43%, Eff: 1.08, Single: 95.32187%
#     lambda=0.31: CAL: Coverage: 88.09%, Eff: 1.07, Single: 95.37422%
#     lambda=0.36: CAL: Coverage: 87.76%, Eff: 1.06, Single: 95.42746%
#     lambda=0.41: CAL: Coverage: 87.48%, Eff: 1.05, Single: 95.47394%
#     lambda=0.46: CAL: Coverage: 87.08%, Eff: 1.04, Single: 95.56045%
#     lambda=0.51: CAL: Coverage: 86.89%, Eff: 1.04, Single: 95.61676%
#     lambda=0.56: CAL: Coverage: 86.50%, Eff: 1.03, Single: 95.54781%
#     lambda=0.61: CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.57876%
#     lambda=0.66: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%
#     lambda=0.71: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%
#     lambda=0.76: CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.64657%
#     lambda=0.81: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%
#     lambda=0.86: CAL: Coverage: 86.08%, Eff: 1.02, Single: 95.63875%
#     lambda=0.91: CAL: Coverage: 85.82%, Eff: 1.01, Single: 95.63207%
#     lambda=0.96: CAL: Coverage: 85.40%, Eff: 1.00, Single: 95.69575%
# CLUSTERING K=80
#     lambda=0.01: CAL: Coverage: 90.10%, Eff: 1.14, Single: 94.94709%
#     lambda=0.06: CAL: Coverage: 89.75%, Eff: 1.12, Single: 95.03163%
#     lambda=0.11: CAL: Coverage: 89.46%, Eff: 1.11, Single: 95.11268%
#     lambda=0.16: CAL: Coverage: 89.15%, Eff: 1.10, Single: 95.23001%
#     lambda=0.21: CAL: Coverage: 88.83%, Eff: 1.09, Single: 95.16801%
#     lambda=0.26: CAL: Coverage: 88.41%, Eff: 1.08, Single: 95.33368%
#     lambda=0.31: CAL: Coverage: 88.18%, Eff: 1.08, Single: 95.33976%
#     lambda=0.36: CAL: Coverage: 87.85%, Eff: 1.06, Single: 95.41856%
#     lambda=0.41: CAL: Coverage: 87.64%, Eff: 1.06, Single: 95.45690%
#     lambda=0.46: CAL: Coverage: 87.20%, Eff: 1.05, Single: 95.53745%
#     lambda=0.51: CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.62969%
#     lambda=0.56: CAL: Coverage: 86.50%, Eff: 1.03, Single: 95.54839%
#     lambda=0.61: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.62025%
#     lambda=0.66: CAL: Coverage: 85.91%, Eff: 1.01, Single: 95.64267%
#     lambda=0.71: CAL: Coverage: 85.50%, Eff: 1.00, Single: 95.68622%
#     lambda=0.76: CAL: Coverage: 85.04%, Eff: 0.99, Single: 95.74304%
#     lambda=0.81: CAL: Coverage: 84.83%, Eff: 0.98, Single: 95.84935%
#     lambda=0.86: CAL: Coverage: 84.05%, Eff: 0.97, Single: 95.92934%
#     lambda=0.91: CAL: Coverage: 83.50%, Eff: 0.95, Single: 96.06390%
#     lambda=0.96: CAL: Coverage: 82.97%, Eff: 0.94, Single: 96.08596%
# CLUSTERING K=100
#     lambda=0.01: CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97221%
#     lambda=0.06: CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.02107%
#     lambda=0.11: CAL: Coverage: 89.47%, Eff: 1.11, Single: 95.11204%
#     lambda=0.16: CAL: Coverage: 89.25%, Eff: 1.10, Single: 95.21631%
#     lambda=0.21: CAL: Coverage: 88.87%, Eff: 1.09, Single: 95.12957%
#     lambda=0.26: CAL: Coverage: 88.41%, Eff: 1.08, Single: 95.33368%
#     lambda=0.31: CAL: Coverage: 88.04%, Eff: 1.07, Single: 95.37782%
#     lambda=0.36: CAL: Coverage: 87.72%, Eff: 1.06, Single: 95.44219%
#     lambda=0.41: CAL: Coverage: 87.16%, Eff: 1.05, Single: 95.54750%
#     lambda=0.46: CAL: Coverage: 86.90%, Eff: 1.04, Single: 95.61732%
#     lambda=0.51: CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.55957%
#     lambda=0.56: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.62025%
#     lambda=0.61: CAL: Coverage: 85.85%, Eff: 1.01, Single: 95.63150%
#     lambda=0.66: CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.68512%
#     lambda=0.71: CAL: Coverage: 85.27%, Eff: 1.00, Single: 95.67450%
#     lambda=0.76: CAL: Coverage: 85.16%, Eff: 0.99, Single: 95.71190%
#     lambda=0.81: CAL: Coverage: 85.04%, Eff: 0.99, Single: 95.74304%
#     lambda=0.86: CAL: Coverage: 84.93%, Eff: 0.99, Single: 95.79595%
#     lambda=0.91: CAL: Coverage: 84.90%, Eff: 0.99, Single: 95.81998%
#     lambda=0.96: CAL: Coverage: 84.71%, Eff: 0.98, Single: 95.95131%
# CLUSTERING K=120
#     lambda=0.01: CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97155%
#     lambda=0.06: CAL: Coverage: 89.76%, Eff: 1.12, Single: 95.04415%
#     lambda=0.11: CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13315%
#     lambda=0.16: CAL: Coverage: 89.19%, Eff: 1.10, Single: 95.22938%
#     lambda=0.21: CAL: Coverage: 89.00%, Eff: 1.10, Single: 95.16045%
#     lambda=0.26: CAL: Coverage: 88.55%, Eff: 1.09, Single: 95.24430%
#     lambda=0.31: CAL: Coverage: 88.21%, Eff: 1.08, Single: 95.28707%
#     lambda=0.36: CAL: Coverage: 88.04%, Eff: 1.07, Single: 95.39021%
#     lambda=0.41: CAL: Coverage: 87.62%, Eff: 1.06, Single: 95.45631%
#     lambda=0.46: CAL: Coverage: 87.22%, Eff: 1.05, Single: 95.52625%
#     lambda=0.51: CAL: Coverage: 86.96%, Eff: 1.04, Single: 95.58976%
#     lambda=0.56: CAL: Coverage: 86.52%, Eff: 1.03, Single: 95.56014%
#     lambda=0.61: CAL: Coverage: 86.44%, Eff: 1.03, Single: 95.55298%
#     lambda=0.66: CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.64657%
#     lambda=0.71: CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.68512%
#     lambda=0.76: CAL: Coverage: 85.06%, Eff: 0.99, Single: 95.74250%
#     lambda=0.81: CAL: Coverage: 84.57%, Eff: 0.98, Single: 95.95235%
#     lambda=0.86: CAL: Coverage: 83.82%, Eff: 0.96, Single: 96.02251%
#     lambda=0.91: CAL: Coverage: 83.21%, Eff: 0.95, Single: 96.06239%
#     lambda=0.96: CAL: Coverage: 82.93%, Eff: 0.94, Single: 96.08545%
# CLUSTERING K=140
#     lambda=0.01: CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97221%
#     lambda=0.06: CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.03359%
#     lambda=0.11: CAL: Coverage: 89.42%, Eff: 1.11, Single: 95.15580%
#     lambda=0.16: CAL: Coverage: 89.22%, Eff: 1.10, Single: 95.22938%
#     lambda=0.21: CAL: Coverage: 88.85%, Eff: 1.09, Single: 95.15562%
#     lambda=0.26: CAL: Coverage: 88.43%, Eff: 1.08, Single: 95.32187%
#     lambda=0.31: CAL: Coverage: 88.12%, Eff: 1.07, Single: 95.37302%
#     lambda=0.36: CAL: Coverage: 87.74%, Eff: 1.06, Single: 95.45337%
#     lambda=0.41: CAL: Coverage: 87.33%, Eff: 1.05, Single: 95.51506%
#     lambda=0.46: CAL: Coverage: 86.94%, Eff: 1.04, Single: 95.62856%
#     lambda=0.51: CAL: Coverage: 86.64%, Eff: 1.03, Single: 95.60837%
#     lambda=0.56: CAL: Coverage: 86.46%, Eff: 1.03, Single: 95.52604%
#     lambda=0.61: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63369%
#     lambda=0.66: CAL: Coverage: 85.79%, Eff: 1.01, Single: 95.62034%
#     lambda=0.71: CAL: Coverage: 85.25%, Eff: 1.00, Single: 95.67394%
#     lambda=0.76: CAL: Coverage: 84.88%, Eff: 0.99, Single: 95.83333%
#     lambda=0.81: CAL: Coverage: 84.44%, Eff: 0.97, Single: 95.93194%
#     lambda=0.86: CAL: Coverage: 83.86%, Eff: 0.96, Single: 95.99591%
#     lambda=0.91: CAL: Coverage: 83.60%, Eff: 0.95, Single: 96.03783%
#     lambda=0.96: CAL: Coverage: 83.06%, Eff: 0.94, Single: 96.07166%
# CLUSTERING K=160
#     lambda=0.01: CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94709%
#     lambda=0.06: CAL: Coverage: 89.80%, Eff: 1.13, Single: 95.03097%
#     lambda=0.11: CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13187%
#     lambda=0.16: CAL: Coverage: 89.37%, Eff: 1.11, Single: 95.19634%
#     lambda=0.21: CAL: Coverage: 89.21%, Eff: 1.10, Single: 95.22938%
#     lambda=0.26: CAL: Coverage: 88.79%, Eff: 1.09, Single: 95.16612%
#     lambda=0.31: CAL: Coverage: 88.38%, Eff: 1.08, Single: 95.33307%
#     lambda=0.36: CAL: Coverage: 88.16%, Eff: 1.07, Single: 95.34279%
#     lambda=0.41: CAL: Coverage: 88.01%, Eff: 1.07, Single: 95.42153%
#     lambda=0.46: CAL: Coverage: 87.70%, Eff: 1.06, Single: 95.43101%
#     lambda=0.51: CAL: Coverage: 87.48%, Eff: 1.05, Single: 95.47453%
#     lambda=0.56: CAL: Coverage: 87.28%, Eff: 1.05, Single: 95.52683%
#     lambda=0.61: CAL: Coverage: 87.04%, Eff: 1.04, Single: 95.55987%
#     lambda=0.66: CAL: Coverage: 86.91%, Eff: 1.04, Single: 95.61676%
#     lambda=0.71: CAL: Coverage: 86.59%, Eff: 1.03, Single: 95.59545%
#     lambda=0.76: CAL: Coverage: 86.24%, Eff: 1.02, Single: 95.56644%
#     lambda=0.81: CAL: Coverage: 86.17%, Eff: 1.02, Single: 95.62251%
#     lambda=0.86: CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.61573%
#     lambda=0.91: CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.56644%
#     lambda=0.96: CAL: Coverage: 86.25%, Eff: 1.02, Single: 95.56644%
# CLUSTERING K=180
#     lambda=0.01: CAL: Coverage: 90.15%, Eff: 1.14, Single: 94.95965%
#     lambda=0.06: CAL: Coverage: 89.89%, Eff: 1.13, Single: 95.01517%
#     lambda=0.11: CAL: Coverage: 89.56%, Eff: 1.12, Single: 95.13059%
#     lambda=0.16: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.19885%
#     lambda=0.21: CAL: Coverage: 89.21%, Eff: 1.10, Single: 95.22938%
#     lambda=0.26: CAL: Coverage: 88.93%, Eff: 1.10, Single: 95.15057%
#     lambda=0.31: CAL: Coverage: 88.62%, Eff: 1.09, Single: 95.21886%
#     lambda=0.36: CAL: Coverage: 88.31%, Eff: 1.08, Single: 95.32552%
#     lambda=0.41: CAL: Coverage: 88.07%, Eff: 1.07, Single: 95.38781%
#     lambda=0.46: CAL: Coverage: 87.82%, Eff: 1.06, Single: 95.41975%
#     lambda=0.51: CAL: Coverage: 87.62%, Eff: 1.06, Single: 95.45690%
#     lambda=0.56: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.50213%
#     lambda=0.61: CAL: Coverage: 87.12%, Eff: 1.04, Single: 95.52393%
#     lambda=0.66: CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.61676%
#     lambda=0.71: CAL: Coverage: 86.75%, Eff: 1.03, Single: 95.60950%
#     lambda=0.76: CAL: Coverage: 86.48%, Eff: 1.03, Single: 95.53779%
#     lambda=0.81: CAL: Coverage: 86.44%, Eff: 1.03, Single: 95.55298%
#     lambda=0.86: CAL: Coverage: 86.28%, Eff: 1.02, Single: 95.54066%
#     lambda=0.91: CAL: Coverage: 86.20%, Eff: 1.02, Single: 95.60737%
#     lambda=0.96: CAL: Coverage: 86.32%, Eff: 1.02, Single: 95.51489%
# CLUSTERING K=200
#     lambda=0.01: CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94709%
#     lambda=0.06: CAL: Coverage: 89.87%, Eff: 1.13, Single: 95.01385%
#     lambda=0.11: CAL: Coverage: 89.59%, Eff: 1.12, Single: 95.14117%
#     lambda=0.16: CAL: Coverage: 89.28%, Eff: 1.10, Single: 95.22813%
#     lambda=0.21: CAL: Coverage: 89.05%, Eff: 1.10, Single: 95.17034%
#     lambda=0.26: CAL: Coverage: 88.78%, Eff: 1.09, Single: 95.21762%
#     lambda=0.31: CAL: Coverage: 88.38%, Eff: 1.08, Single: 95.33246%
#     lambda=0.36: CAL: Coverage: 88.10%, Eff: 1.07, Single: 95.38602%
#     lambda=0.41: CAL: Coverage: 87.77%, Eff: 1.06, Single: 95.43746%
#     lambda=0.46: CAL: Coverage: 87.53%, Eff: 1.05, Single: 95.47394%
#     lambda=0.51: CAL: Coverage: 87.14%, Eff: 1.05, Single: 95.53514%
#     lambda=0.56: CAL: Coverage: 86.72%, Eff: 1.03, Single: 95.59773%
#     lambda=0.61: CAL: Coverage: 86.31%, Eff: 1.02, Single: 95.52720%
#     lambda=0.66: CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.63369%
#     lambda=0.71: CAL: Coverage: 85.75%, Eff: 1.01, Single: 95.64491%
#     lambda=0.76: CAL: Coverage: 85.43%, Eff: 1.00, Single: 95.67227%
#     lambda=0.81: CAL: Coverage: 85.02%, Eff: 0.99, Single: 95.77032%
#     lambda=0.86: CAL: Coverage: 84.91%, Eff: 0.99, Single: 95.80769%
#     lambda=0.91: CAL: Coverage: 84.81%, Eff: 0.98, Single: 95.84080%
#     lambda=0.96: CAL: Coverage: 84.86%, Eff: 0.99, Single: 95.82266%

# %%
clustering_results_global
# Out:
# [('BASELINE',
#   {'qhat': np.float32(-1.8755414),
#    'coverage': np.float64(0.9016),
#    'efficiency': np.float64(1.1376),
#    'singleton_cov': np.float64(0.9496955255493779),
#    'result_str': 'Baseline CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%'}),
#  ('K=20, lambda=0.01',
#   {'qhat': np.float64(-1.9079369115829468),
#    'coverage': np.float64(0.9004),
#    'efficiency': np.float64(1.1332),
#    'singleton_cov': np.float64(0.9498876107364802),
#    'result_str': 'CAL: Coverage: 90.04%, Eff: 1.13, Single: 94.98876%'}),
#  ('K=20, lambda=0.06',
#   {'qhat': np.float64(-2.068760538101196),
#    'coverage': np.float64(0.8944),
#    'efficiency': np.float64(1.1115),
#    'singleton_cov': np.float64(0.9516255899318301),
#    'result_str': 'CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16256%'}),
#  ('K=20, lambda=0.11',
#   {'qhat': np.float64(-2.2221137428283693),
#    'coverage': np.float64(0.8886),
#    'efficiency': np.float64(1.0936),
#    'singleton_cov': np.float64(0.9512893982808023),
#    'result_str': 'CAL: Coverage: 88.86%, Eff: 1.09, Single: 95.12894%'}),
#  ('K=20, lambda=0.16',
#   {'qhat': np.float64(-2.3488946199417113),
#    'coverage': np.float64(0.882),
#    'efficiency': np.float64(1.0762),
#    'singleton_cov': np.float64(0.9532552083333333),
#    'result_str': 'CAL: Coverage: 88.20%, Eff: 1.08, Single: 95.32552%'}),
#  ('K=20, lambda=0.21',
#   {'qhat': np.float64(-2.496129536628723),
#    'coverage': np.float64(0.876),
#    'efficiency': np.float64(1.0558),
#    'singleton_cov': np.float64(0.9547042836806005),
#    'result_str': 'CAL: Coverage: 87.60%, Eff: 1.06, Single: 95.47043%'}),
#  ('K=20, lambda=0.26',
#   {'qhat': np.float64(-2.637170186042786),
#    'coverage': np.float64(0.8688),
#    'efficiency': np.float64(1.0376),
#    'singleton_cov': np.float64(0.9562912194491142),
#    'result_str': 'CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.62912%'}),
#  ('K=20, lambda=0.31',
#   {'qhat': np.float64(-2.8010596895217894),
#    'coverage': np.float64(0.8605),
#    'efficiency': np.float64(1.0158),
#    'singleton_cov': np.float64(0.9565217391304348),
#    'result_str': 'CAL: Coverage: 86.05%, Eff: 1.02, Single: 95.65217%'}),
#  ('K=20, lambda=0.36',
#   {'qhat': np.float64(-2.9152576327323914),
#    'coverage': np.float64(0.8546),
#    'efficiency': np.float64(1.0017),
#    'singleton_cov': np.float64(0.956728299948639),
#    'result_str': 'CAL: Coverage: 85.46%, Eff: 1.00, Single: 95.67283%'}),
#  ('K=20, lambda=0.41',
#   {'qhat': np.float64(-3.0343485736846922),
#    'coverage': np.float64(0.849),
#    'efficiency': np.float64(0.9869),
#    'singleton_cov': np.float64(0.9582051282051282),
#    'result_str': 'CAL: Coverage: 84.90%, Eff: 0.99, Single: 95.82051%'}),
#  ('K=20, lambda=0.46',
#   {'qhat': np.float64(-3.1429221987724305),
#    'coverage': np.float64(0.8425),
#    'efficiency': np.float64(0.9705),
#    'singleton_cov': np.float64(0.959191505692721),
#    'result_str': 'CAL: Coverage: 84.25%, Eff: 0.97, Single: 95.91915%'}),
#  ('K=20, lambda=0.51',
#   {'qhat': np.float64(-3.2542052173614504),
#    'coverage': np.float64(0.8368),
#    'efficiency': np.float64(0.9558),
#    'singleton_cov': np.float64(0.9605263157894737),
#    'result_str': 'CAL: Coverage: 83.68%, Eff: 0.96, Single: 96.05263%'}),
#  ('K=20, lambda=0.56',
#   {'qhat': np.float64(-3.3489245796203617),
#    'coverage': np.float64(0.8314),
#    'efficiency': np.float64(0.9453),
#    'singleton_cov': np.float64(0.9604859335038363),
#    'result_str': 'CAL: Coverage: 83.14%, Eff: 0.95, Single: 96.04859%'}),
#  ('K=20, lambda=0.61',
#   {'qhat': np.float64(-3.4285229229927063),
#    'coverage': np.float64(0.8263),
#    'efficiency': np.float64(0.9361),
#    'singleton_cov': np.float64(0.9606611993849308),
#    'result_str': 'CAL: Coverage: 82.63%, Eff: 0.94, Single: 96.06612%'}),
#  ('K=20, lambda=0.66',
#   {'qhat': np.float64(-3.52413519859314),
#    'coverage': np.float64(0.8204),
#    'efficiency': np.float64(0.9251),
#    'singleton_cov': np.float64(0.9608371854134566),
#    'result_str': 'CAL: Coverage: 82.04%, Eff: 0.93, Single: 96.08372%'}),
#  ('K=20, lambda=0.71',
#   {'qhat': np.float64(-3.584357657432556),
#    'coverage': np.float64(0.8168),
#    'efficiency': np.float64(0.9189),
#    'singleton_cov': np.float64(0.9614988411022405),
#    'result_str': 'CAL: Coverage: 81.68%, Eff: 0.92, Single: 96.14988%'}),
#  ('K=20, lambda=0.76',
#   {'qhat': np.float64(-3.631246918439865),
#    'coverage': np.float64(0.8143),
#    'efficiency': np.float64(0.9141),
#    'singleton_cov': np.float64(0.9612512873326468),
#    'result_str': 'CAL: Coverage: 81.43%, Eff: 0.91, Single: 96.12513%'}),
#  ('K=20, lambda=0.81',
#   {'qhat': np.float64(-3.674091997146607),
#    'coverage': np.float64(0.8116),
#    'efficiency': np.float64(0.9098),
#    'singleton_cov': np.float64(0.9611863313990974),
#    'result_str': 'CAL: Coverage: 81.16%, Eff: 0.91, Single: 96.11863%'}),
#  ('K=20, lambda=0.86',
#   {'qhat': np.float64(-3.7067468309402467),
#    'coverage': np.float64(0.8099),
#    'efficiency': np.float64(0.9069),
#    'singleton_cov': np.float64(0.9613994319648851),
#    'result_str': 'CAL: Coverage: 80.99%, Eff: 0.91, Single: 96.13994%'}),
#  ('K=20, lambda=0.91',
#   {'qhat': np.float64(-3.7232253217697147),
#    'coverage': np.float64(0.8092),
#    'efficiency': np.float64(0.9057),
#    'singleton_cov': np.float64(0.9617472215042646),
#    'result_str': 'CAL: Coverage: 80.92%, Eff: 0.91, Single: 96.17472%'}),
#  ('K=20, lambda=0.96',
#   {'qhat': np.float64(-3.844489388456568),
#    'coverage': np.float64(0.803),
#    'efficiency': np.float64(0.893),
#    'singleton_cov': np.float64(0.9635349078640021),
#    'result_str': 'CAL: Coverage: 80.30%, Eff: 0.89, Single: 96.35349%'}),
#  ('K=40, lambda=0.01',
#   {'qhat': np.float64(-1.9066819620132447),
#    'coverage': np.float64(0.9004),
#    'efficiency': np.float64(1.1335),
#    'singleton_cov': np.float64(0.9498743552440153),
#    'result_str': 'CAL: Coverage: 90.04%, Eff: 1.13, Single: 94.98744%'}),
#  ('K=40, lambda=0.06',
#   {'qhat': np.float64(-1.994558711051941),
#    'coverage': np.float64(0.8968),
#    'efficiency': np.float64(1.1219),
#    'singleton_cov': np.float64(0.9503686150605581),
#    'result_str': 'CAL: Coverage: 89.68%, Eff: 1.12, Single: 95.03686%'}),
#  ('K=40, lambda=0.11',
#   {'qhat': np.float64(-2.095846428871155),
#    'coverage': np.float64(0.8937),
#    'efficiency': np.float64(1.1087),
#    'singleton_cov': np.float64(0.9517015706806282),
#    'result_str': 'CAL: Coverage: 89.37%, Eff: 1.11, Single: 95.17016%'}),
#  ('K=40, lambda=0.16',
#   {'qhat': np.float64(-2.21197699546814),
#    'coverage': np.float64(0.8893),
#    'efficiency': np.float64(1.0953),
#    'singleton_cov': np.float64(0.9515056707078607),
#    'result_str': 'CAL: Coverage: 88.93%, Eff: 1.10, Single: 95.15057%'}),
#  ('K=40, lambda=0.21',
#   {'qhat': np.float64(-2.2971434450149535),
#    'coverage': np.float64(0.8847),
#    'efficiency': np.float64(1.0835),
#    'singleton_cov': np.float64(0.9528277299973938),
#    'result_str': 'CAL: Coverage: 88.47%, Eff: 1.08, Single: 95.28277%'}),
#  ('K=40, lambda=0.26',
#   {'qhat': np.float64(-2.3917815828323366),
#    'coverage': np.float64(0.8808),
#    'efficiency': np.float64(1.0713),
#    'singleton_cov': np.float64(0.9537422037422038),
#    'result_str': 'CAL: Coverage: 88.08%, Eff: 1.07, Single: 95.37422%'}),
#  ('K=40, lambda=0.31',
#   {'qhat': np.float64(-2.466695499420166),
#    'coverage': np.float64(0.8777),
#    'efficiency': np.float64(1.0611),
#    'singleton_cov': np.float64(0.9543805080352514),
#    'result_str': 'CAL: Coverage: 87.77%, Eff: 1.06, Single: 95.43805%'}),
#  ('K=40, lambda=0.36',
#   {'qhat': np.float64(-2.5364651370048525),
#    'coverage': np.float64(0.8742),
#    'efficiency': np.float64(1.0506),
#    'singleton_cov': np.float64(0.9552509053285049),
#    'result_str': 'CAL: Coverage: 87.42%, Eff: 1.05, Single: 95.52509%'}),
#  ('K=40, lambda=0.41',
#   {'qhat': np.float64(-2.6123566579818727),
#    'coverage': np.float64(0.8695),
#    'efficiency': np.float64(1.0396),
#    'singleton_cov': np.float64(0.956150562669771),
#    'result_str': 'CAL: Coverage: 86.95%, Eff: 1.04, Single: 95.61506%'}),
#  ('K=40, lambda=0.46',
#   {'qhat': np.float64(-2.6991270565986634),
#    'coverage': np.float64(0.8651),
#    'efficiency': np.float64(1.0295),
#    'singleton_cov': np.float64(0.9556014455343315),
#    'result_str': 'CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.56014%'}),
#  ('K=40, lambda=0.51',
#   {'qhat': np.float64(-2.761444284915924),
#    'coverage': np.float64(0.8619),
#    'efficiency': np.float64(1.0202),
#    'singleton_cov': np.float64(0.9561968564802886),
#    'result_str': 'CAL: Coverage: 86.19%, Eff: 1.02, Single: 95.61969%'}),
#  ('K=40, lambda=0.56',
#   {'qhat': np.float64(-2.824061651229859),
#    'coverage': np.float64(0.8592),
#    'efficiency': np.float64(1.0128),
#    'singleton_cov': np.float64(0.9562925825941637),
#    'result_str': 'CAL: Coverage: 85.92%, Eff: 1.01, Single: 95.62926%'}),
#  ('K=40, lambda=0.61',
#   {'qhat': np.float64(-2.8662472319602967),
#    'coverage': np.float64(0.8575),
#    'efficiency': np.float64(1.0087),
#    'singleton_cov': np.float64(0.9564491264131552),
#    'result_str': 'CAL: Coverage: 85.75%, Eff: 1.01, Single: 95.64491%'}),
#  ('K=40, lambda=0.66',
#   {'qhat': np.float64(-2.891396281719208),
#    'coverage': np.float64(0.8559),
#    'efficiency': np.float64(1.0048),
#    'singleton_cov': np.float64(0.9567171846904701),
#    'result_str': 'CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.67172%'}),
#  ('K=40, lambda=0.71',
#   {'qhat': np.float64(-2.926312572956085),
#    'coverage': np.float64(0.8541),
#    'efficiency': np.float64(1.0008),
#    'singleton_cov': np.float64(0.9568345323741008),
#    'result_str': 'CAL: Coverage: 85.41%, Eff: 1.00, Single: 95.68345%'}),
#  ('K=40, lambda=0.76',
#   {'qhat': np.float64(-2.9458134603500366),
#    'coverage': np.float64(0.8527),
#    'efficiency': np.float64(0.9975),
#    'singleton_cov': np.float64(0.9567449621357977),
#    'result_str': 'CAL: Coverage: 85.27%, Eff: 1.00, Single: 95.67450%'}),
#  ('K=40, lambda=0.81',
#   {'qhat': np.float64(-2.977254409790039),
#    'coverage': np.float64(0.8509),
#    'efficiency': np.float64(0.9929),
#    'singleton_cov': np.float64(0.9572693442833312),
#    'result_str': 'CAL: Coverage: 85.09%, Eff: 0.99, Single: 95.72693%'}),
#  ('K=40, lambda=0.86',
#   {'qhat': np.float64(-2.9690654528141023),
#    'coverage': np.float64(0.8513),
#    'efficiency': np.float64(0.994),
#    'singleton_cov': np.float64(0.957135523613963),
#    'result_str': 'CAL: Coverage: 85.13%, Eff: 0.99, Single: 95.71355%'}),
#  ('K=40, lambda=0.91',
#   {'qhat': np.float64(-2.958465875387192),
#    'coverage': np.float64(0.8519),
#    'efficiency': np.float64(0.9958),
#    'singleton_cov': np.float64(0.9568677792041078),
#    'result_str': 'CAL: Coverage: 85.19%, Eff: 1.00, Single: 95.68678%'}),
#  ('K=40, lambda=0.96',
#   {'qhat': np.float64(-2.971397809386253),
#    'coverage': np.float64(0.8512),
#    'efficiency': np.float64(0.9937),
#    'singleton_cov': np.float64(0.9571410239958937),
#    'result_str': 'CAL: Coverage: 85.12%, Eff: 0.99, Single: 95.71410%'}),
#  ('K=60, lambda=0.01',
#   {'qhat': np.float64(-1.889088921546936),
#    'coverage': np.float64(0.9014),
#    'efficiency': np.float64(1.1363),
#    'singleton_cov': np.float64(0.9494775823303796),
#    'result_str': 'CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94776%'}),
#  ('K=60, lambda=0.06',
#   {'qhat': np.float64(-1.9699340534210206),
#    'coverage': np.float64(0.8979),
#    'efficiency': np.float64(1.125),
#    'singleton_cov': np.float64(0.9503162888771745),
#    'result_str': 'CAL: Coverage: 89.79%, Eff: 1.12, Single: 95.03163%'}),
#  ('K=60, lambda=0.11',
#   {'qhat': np.float64(-2.071489496231079),
#    'coverage': np.float64(0.8944),
#    'efficiency': np.float64(1.1111),
#    'singleton_cov': np.float64(0.9516509433962265),
#    'result_str': 'CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16509%'}),
#  ('K=60, lambda=0.16',
#   {'qhat': np.float64(-2.1764060926437376),
#    'coverage': np.float64(0.8908),
#    'efficiency': np.float64(1.0995),
#    'singleton_cov': np.float64(0.9517034329721968),
#    'result_str': 'CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%'}),
#  ('K=60, lambda=0.21',
#   {'qhat': np.float64(-2.2319846212863923),
#    'coverage': np.float64(0.8884),
#    'efficiency': np.float64(1.0925),
#    'singleton_cov': np.float64(0.9516864175022789),
#    'result_str': 'CAL: Coverage: 88.84%, Eff: 1.09, Single: 95.16864%'}),
#  ('K=60, lambda=0.26',
#   {'qhat': np.float64(-2.304733352661133),
#    'coverage': np.float64(0.8843),
#    'efficiency': np.float64(1.0821),
#    'singleton_cov': np.float64(0.95321866041178),
#    'result_str': 'CAL: Coverage: 88.43%, Eff: 1.08, Single: 95.32187%'}),
#  ('K=60, lambda=0.31',
#   {'qhat': np.float64(-2.38933963060379),
#    'coverage': np.float64(0.8809),
#    'efficiency': np.float64(1.0715),
#    'singleton_cov': np.float64(0.9537422037422038),
#    'result_str': 'CAL: Coverage: 88.09%, Eff: 1.07, Single: 95.37422%'}),
#  ('K=60, lambda=0.36',
#   {'qhat': np.float64(-2.468384122848511),
#    'coverage': np.float64(0.8776),
#    'efficiency': np.float64(1.0607),
#    'singleton_cov': np.float64(0.9542746113989637),
#    'result_str': 'CAL: Coverage: 87.76%, Eff: 1.06, Single: 95.42746%'}),
#  ('K=60, lambda=0.41',
#   {'qhat': np.float64(-2.518627478480339),
#    'coverage': np.float64(0.8748),
#    'efficiency': np.float64(1.0527),
#    'singleton_cov': np.float64(0.9547394284236389),
#    'result_str': 'CAL: Coverage: 87.48%, Eff: 1.05, Single: 95.47394%'}),
#  ('K=60, lambda=0.46',
#   {'qhat': np.float64(-2.587878115177155),
#    'coverage': np.float64(0.8708),
#    'efficiency': np.float64(1.0436),
#    'singleton_cov': np.float64(0.9556044524980585),
#    'result_str': 'CAL: Coverage: 87.08%, Eff: 1.04, Single: 95.56045%'}),
#  ('K=60, lambda=0.51',
#   {'qhat': np.float64(-2.6327837896347046),
#    'coverage': np.float64(0.8689),
#    'efficiency': np.float64(1.0379),
#    'singleton_cov': np.float64(0.956167571761055),
#    'result_str': 'CAL: Coverage: 86.89%, Eff: 1.04, Single: 95.61676%'}),
#  ('K=60, lambda=0.56',
#   {'qhat': np.float64(-2.7016829013824464),
#    'coverage': np.float64(0.865),
#    'efficiency': np.float64(1.0294),
#    'singleton_cov': np.float64(0.9554781262098335),
#    'result_str': 'CAL: Coverage: 86.50%, Eff: 1.03, Single: 95.54781%'}),
#  ('K=60, lambda=0.61',
#   {'qhat': np.float64(-2.749038344621658),
#    'coverage': np.float64(0.8622),
#    'efficiency': np.float64(1.0218),
#    'singleton_cov': np.float64(0.9557875741170405),
#    'result_str': 'CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.57876%'}),
#  ('K=60, lambda=0.66',
#   {'qhat': np.float64(-2.769514389038086),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0197),
#    'singleton_cov': np.float64(0.9563313152131908),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%'}),
#  ('K=60, lambda=0.71',
#   {'qhat': np.float64(-2.766695349216461),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0197),
#    'singleton_cov': np.float64(0.9563313152131908),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%'}),
#  ('K=60, lambda=0.76',
#   {'qhat': np.float64(-2.7810178565979005),
#    'coverage': np.float64(0.8613),
#    'efficiency': np.float64(1.0183),
#    'singleton_cov': np.float64(0.9564657393096342),
#    'result_str': 'CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.64657%'}),
#  ('K=60, lambda=0.81',
#   {'qhat': np.float64(-2.7675258469581605),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0197),
#    'singleton_cov': np.float64(0.9563313152131908),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%'}),
#  ('K=60, lambda=0.86',
#   {'qhat': np.float64(-2.7922335016727446),
#    'coverage': np.float64(0.8608),
#    'efficiency': np.float64(1.0167),
#    'singleton_cov': np.float64(0.9563874951756078),
#    'result_str': 'CAL: Coverage: 86.08%, Eff: 1.02, Single: 95.63875%'}),
#  ('K=60, lambda=0.91',
#   {'qhat': np.float64(-2.8478606480360034),
#    'coverage': np.float64(0.8582),
#    'efficiency': np.float64(1.0103),
#    'singleton_cov': np.float64(0.9563206577595067),
#    'result_str': 'CAL: Coverage: 85.82%, Eff: 1.01, Single: 95.63207%'}),
#  ('K=60, lambda=0.96',
#   {'qhat': np.float64(-2.9272949698567388),
#    'coverage': np.float64(0.854),
#    'efficiency': np.float64(1.0005),
#    'singleton_cov': np.float64(0.9569574714120519),
#    'result_str': 'CAL: Coverage: 85.40%, Eff: 1.00, Single: 95.69575%'}),
#  ('K=80, lambda=0.01',
#   {'qhat': np.float64(-1.8924807620048523),
#    'coverage': np.float64(0.901),
#    'efficiency': np.float64(1.1356),
#    'singleton_cov': np.float64(0.9494708994708995),
#    'result_str': 'CAL: Coverage: 90.10%, Eff: 1.14, Single: 94.94709%'}),
#  ('K=80, lambda=0.06',
#   {'qhat': np.float64(-1.9771774482727051),
#    'coverage': np.float64(0.8975),
#    'efficiency': np.float64(1.1242),
#    'singleton_cov': np.float64(0.9503162888771745),
#    'result_str': 'CAL: Coverage: 89.75%, Eff: 1.12, Single: 95.03163%'}),
#  ('K=80, lambda=0.11',
#   {'qhat': np.float64(-2.061874134540558),
#    'coverage': np.float64(0.8946),
#    'efficiency': np.float64(1.1123),
#    'singleton_cov': np.float64(0.9511268343815513),
#    'result_str': 'CAL: Coverage: 89.46%, Eff: 1.11, Single: 95.11268%'}),
#  ('K=80, lambda=0.16',
#   {'qhat': np.float64(-2.1640256309509276),
#    'coverage': np.float64(0.8915),
#    'efficiency': np.float64(1.1012),
#    'singleton_cov': np.float64(0.9523000522739153),
#    'result_str': 'CAL: Coverage: 89.15%, Eff: 1.10, Single: 95.23001%'}),
#  ('K=80, lambda=0.21',
#   {'qhat': np.float64(-2.234134931564331),
#    'coverage': np.float64(0.8883),
#    'efficiency': np.float64(1.0924),
#    'singleton_cov': np.float64(0.9516801250325606),
#    'result_str': 'CAL: Coverage: 88.83%, Eff: 1.09, Single: 95.16801%'}),
#  ('K=80, lambda=0.26',
#   {'qhat': np.float64(-2.309373304843903),
#    'coverage': np.float64(0.8841),
#    'efficiency': np.float64(1.0817),
#    'singleton_cov': np.float64(0.9533368091762252),
#    'result_str': 'CAL: Coverage: 88.41%, Eff: 1.08, Single: 95.33368%'}),
#  ('K=80, lambda=0.31',
#   {'qhat': np.float64(-2.355426063537598),
#    'coverage': np.float64(0.8818),
#    'efficiency': np.float64(1.0755),
#    'singleton_cov': np.float64(0.9533975527206456),
#    'result_str': 'CAL: Coverage: 88.18%, Eff: 1.08, Single: 95.33976%'}),
#  ('K=80, lambda=0.36',
#   {'qhat': np.float64(-2.4371138620376587),
#    'coverage': np.float64(0.8785),
#    'efficiency': np.float64(1.0646),
#    'singleton_cov': np.float64(0.954185593770279),
#    'result_str': 'CAL: Coverage: 87.85%, Eff: 1.06, Single: 95.41856%'}),
#  ('K=80, lambda=0.41',
#   {'qhat': np.float64(-2.4889448678493498),
#    'coverage': np.float64(0.8764),
#    'efficiency': np.float64(1.057),
#    'singleton_cov': np.float64(0.9545689878332901),
#    'result_str': 'CAL: Coverage: 87.64%, Eff: 1.06, Single: 95.45690%'}),
#  ('K=80, lambda=0.46',
#   {'qhat': np.float64(-2.571519045829773),
#    'coverage': np.float64(0.872),
#    'efficiency': np.float64(1.0459),
#    'singleton_cov': np.float64(0.9553744664338378),
#    'result_str': 'CAL: Coverage: 87.20%, Eff: 1.05, Single: 95.53745%'}),
#  ('K=80, lambda=0.51',
#   {'qhat': np.float64(-2.637892800346017),
#    'coverage': np.float64(0.8688),
#    'efficiency': np.float64(1.0375),
#    'singleton_cov': np.float64(0.9562968709594001),
#    'result_str': 'CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.62969%'}),
#  ('K=80, lambda=0.56',
#   {'qhat': np.float64(-2.7028948867321017),
#    'coverage': np.float64(0.865),
#    'efficiency': np.float64(1.0293),
#    'singleton_cov': np.float64(0.9554838709677419),
#    'result_str': 'CAL: Coverage: 86.50%, Eff: 1.03, Single: 95.54839%'}),
#  ('K=80, lambda=0.61',
#   {'qhat': np.float64(-2.765281205177307),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0199),
#    'singleton_cov': np.float64(0.9562024990338787),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.62025%'}),
#  ('K=80, lambda=0.66',
#   {'qhat': np.float64(-2.828517942428589),
#    'coverage': np.float64(0.8591),
#    'efficiency': np.float64(1.0123),
#    'singleton_cov': np.float64(0.956426735218509),
#    'result_str': 'CAL: Coverage: 85.91%, Eff: 1.01, Single: 95.64267%'}),
#  ('K=80, lambda=0.71',
#   {'qhat': np.float64(-2.9118370103836058),
#    'coverage': np.float64(0.855),
#    'efficiency': np.float64(1.0022),
#    'singleton_cov': np.float64(0.9568622416228014),
#    'result_str': 'CAL: Coverage: 85.50%, Eff: 1.00, Single: 95.68622%'}),
#  ('K=80, lambda=0.76',
#   {'qhat': np.float64(-2.996711688041687),
#    'coverage': np.float64(0.8504),
#    'efficiency': np.float64(0.9911),
#    'singleton_cov': np.float64(0.9574304397999743),
#    'result_str': 'CAL: Coverage: 85.04%, Eff: 0.99, Single: 95.74304%'}),
#  ('K=80, lambda=0.81',
#   {'qhat': np.float64(-3.050139914751053),
#    'coverage': np.float64(0.8483),
#    'efficiency': np.float64(0.9842),
#    'singleton_cov': np.float64(0.9584934665641814),
#    'result_str': 'CAL: Coverage: 84.83%, Eff: 0.98, Single: 95.84935%'}),
#  ('K=80, lambda=0.86',
#   {'qhat': np.float64(-3.1729897817969324),
#    'coverage': np.float64(0.8405),
#    'efficiency': np.float64(0.9668),
#    'singleton_cov': np.float64(0.9592933947772657),
#    'result_str': 'CAL: Coverage: 84.05%, Eff: 0.97, Single: 95.92934%'}),
#  ('K=80, lambda=0.91',
#   {'qhat': np.float64(-3.2945300179719927),
#    'coverage': np.float64(0.835),
#    'efficiency': np.float64(0.9523),
#    'singleton_cov': np.float64(0.9606389776357828),
#    'result_str': 'CAL: Coverage: 83.50%, Eff: 0.95, Single: 96.06390%'}),
#  ('K=80, lambda=0.96',
#   {'qhat': np.float64(-3.3861773911118505),
#    'coverage': np.float64(0.8297),
#    'efficiency': np.float64(0.9414),
#    'singleton_cov': np.float64(0.9608595548733692),
#    'result_str': 'CAL: Coverage: 82.97%, Eff: 0.94, Single: 96.08596%'}),
#  ('K=100, lambda=0.01',
#   {'qhat': np.float64(-1.8968845653533934),
#    'coverage': np.float64(0.9009),
#    'efficiency': np.float64(1.1351),
#    'singleton_cov': np.float64(0.9497221487165917),
#    'result_str': 'CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97221%'}),
#  ('K=100, lambda=0.06',
#   {'qhat': np.float64(-1.983797311782837),
#    'coverage': np.float64(0.8972),
#    'efficiency': np.float64(1.1233),
#    'singleton_cov': np.float64(0.9502107481559536),
#    'result_str': 'CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.02107%'}),
#  ('K=100, lambda=0.11',
#   {'qhat': np.float64(-2.059904491752386),
#    'coverage': np.float64(0.8947),
#    'efficiency': np.float64(1.1126),
#    'singleton_cov': np.float64(0.9511204298257109),
#    'result_str': 'CAL: Coverage: 89.47%, Eff: 1.11, Single: 95.11204%'}),
#  ('K=100, lambda=0.16',
#   {'qhat': np.float64(-2.140814714431763),
#    'coverage': np.float64(0.8925),
#    'efficiency': np.float64(1.1039),
#    'singleton_cov': np.float64(0.9521631159325579),
#    'result_str': 'CAL: Coverage: 89.25%, Eff: 1.10, Single: 95.21631%'}),
#  ('K=100, lambda=0.21',
#   {'qhat': np.float64(-2.2187856912612913),
#    'coverage': np.float64(0.8887),
#    'efficiency': np.float64(1.0937),
#    'singleton_cov': np.float64(0.9512957416330251),
#    'result_str': 'CAL: Coverage: 88.87%, Eff: 1.09, Single: 95.12957%'}),
#  ('K=100, lambda=0.26',
#   {'qhat': np.float64(-2.3096409726142886),
#    'coverage': np.float64(0.8841),
#    'efficiency': np.float64(1.0817),
#    'singleton_cov': np.float64(0.9533368091762252),
#    'result_str': 'CAL: Coverage: 88.41%, Eff: 1.08, Single: 95.33368%'}),
#  ('K=100, lambda=0.31',
#   {'qhat': np.float64(-2.403342831134796),
#    'coverage': np.float64(0.8804),
#    'efficiency': np.float64(1.0698),
#    'singleton_cov': np.float64(0.953778239418333),
#    'result_str': 'CAL: Coverage: 88.04%, Eff: 1.07, Single: 95.37782%'}),
#  ('K=100, lambda=0.36',
#   {'qhat': np.float64(-2.4764360475540164),
#    'coverage': np.float64(0.8772),
#    'efficiency': np.float64(1.0592),
#    'singleton_cov': np.float64(0.9544218567914023),
#    'result_str': 'CAL: Coverage: 87.72%, Eff: 1.06, Single: 95.44219%'}),
#  ('K=100, lambda=0.41',
#   {'qhat': np.float64(-2.5725783371925353),
#    'coverage': np.float64(0.8716),
#    'efficiency': np.float64(1.0454),
#    'singleton_cov': np.float64(0.9554750194149625),
#    'result_str': 'CAL: Coverage: 87.16%, Eff: 1.05, Single: 95.54750%'}),
#  ('K=100, lambda=0.46',
#   {'qhat': np.float64(-2.6311361408233642),
#    'coverage': np.float64(0.869),
#    'efficiency': np.float64(1.0381),
#    'singleton_cov': np.float64(0.9561732385261797),
#    'result_str': 'CAL: Coverage: 86.90%, Eff: 1.04, Single: 95.61732%'}),
#  ('K=100, lambda=0.51',
#   {'qhat': np.float64(-2.696843341588974),
#    'coverage': np.float64(0.8651),
#    'efficiency': np.float64(1.0298),
#    'singleton_cov': np.float64(0.9555957144701175),
#    'result_str': 'CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.55957%'}),
#  ('K=100, lambda=0.56',
#   {'qhat': np.float64(-2.765207133293152),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0199),
#    'singleton_cov': np.float64(0.9562024990338787),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.62025%'}),
#  ('K=100, lambda=0.61',
#   {'qhat': np.float64(-2.8402328610420224),
#    'coverage': np.float64(0.8585),
#    'efficiency': np.float64(1.011),
#    'singleton_cov': np.float64(0.9563150456122318),
#    'result_str': 'CAL: Coverage: 85.85%, Eff: 1.01, Single: 95.63150%'}),
#  ('K=100, lambda=0.66',
#   {'qhat': np.float64(-2.8929926681518556),
#    'coverage': np.float64(0.8559),
#    'efficiency': np.float64(1.0045),
#    'singleton_cov': np.float64(0.9568511621933993),
#    'result_str': 'CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.68512%'}),
#  ('K=100, lambda=0.71',
#   {'qhat': np.float64(-2.9464170336723328),
#    'coverage': np.float64(0.8527),
#    'efficiency': np.float64(0.9975),
#    'singleton_cov': np.float64(0.9567449621357977),
#    'result_str': 'CAL: Coverage: 85.27%, Eff: 1.00, Single: 95.67450%'}),
#  ('K=100, lambda=0.76',
#   {'qhat': np.float64(-2.9628789901733397),
#    'coverage': np.float64(0.8516),
#    'efficiency': np.float64(0.9949),
#    'singleton_cov': np.float64(0.9571190139940943),
#    'result_str': 'CAL: Coverage: 85.16%, Eff: 0.99, Single: 95.71190%'}),
#  ('K=100, lambda=0.81',
#   {'qhat': np.float64(-2.997051839828491),
#    'coverage': np.float64(0.8504),
#    'efficiency': np.float64(0.9911),
#    'singleton_cov': np.float64(0.9574304397999743),
#    'result_str': 'CAL: Coverage: 85.04%, Eff: 0.99, Single: 95.74304%'}),
#  ('K=100, lambda=0.86',
#   {'qhat': np.float64(-3.020568698644638),
#    'coverage': np.float64(0.8493),
#    'efficiency': np.float64(0.9879),
#    'singleton_cov': np.float64(0.957959497564727),
#    'result_str': 'CAL: Coverage: 84.93%, Eff: 0.99, Single: 95.79595%'}),
#  ('K=100, lambda=0.91',
#   {'qhat': np.float64(-3.033097743988037),
#    'coverage': np.float64(0.849),
#    'efficiency': np.float64(0.987),
#    'singleton_cov': np.float64(0.9581997692011797),
#    'result_str': 'CAL: Coverage: 84.90%, Eff: 0.99, Single: 95.81998%'}),
#  ('K=100, lambda=0.96',
#   {'qhat': np.float64(-3.073627680540085),
#    'coverage': np.float64(0.8471),
#    'efficiency': np.float64(0.9803),
#    'singleton_cov': np.float64(0.959513132607303),
#    'result_str': 'CAL: Coverage: 84.71%, Eff: 0.98, Single: 95.95131%'}),
#  ('K=120, lambda=0.01',
#   {'qhat': np.float64(-1.8950761032104493),
#    'coverage': np.float64(0.9009),
#    'efficiency': np.float64(1.1353),
#    'singleton_cov': np.float64(0.949715495567024),
#    'result_str': 'CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97155%'}),
#  ('K=120, lambda=0.06',
#   {'qhat': np.float64(-1.976497368812561),
#    'coverage': np.float64(0.8976),
#    'efficiency': np.float64(1.1243),
#    'singleton_cov': np.float64(0.9504415447475946),
#    'result_str': 'CAL: Coverage: 89.76%, Eff: 1.12, Single: 95.04415%'}),
#  ('K=120, lambda=0.11',
#   {'qhat': np.float64(-2.049767937660217),
#    'coverage': np.float64(0.8954),
#    'efficiency': np.float64(1.1145),
#    'singleton_cov': np.float64(0.9513314967860422),
#    'result_str': 'CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13315%'}),
#  ('K=120, lambda=0.16',
#   {'qhat': np.float64(-2.153371982574463),
#    'coverage': np.float64(0.8919),
#    'efficiency': np.float64(1.1024),
#    'singleton_cov': np.float64(0.9522938178015946),
#    'result_str': 'CAL: Coverage: 89.19%, Eff: 1.10, Single: 95.22938%'}),
#  ('K=120, lambda=0.21',
#   {'qhat': np.float64(-2.197789678573608),
#    'coverage': np.float64(0.89),
#    'efficiency': np.float64(1.0973),
#    'singleton_cov': np.float64(0.9516044873467258),
#    'result_str': 'CAL: Coverage: 89.00%, Eff: 1.10, Single: 95.16045%'}),
#  ('K=120, lambda=0.26',
#   {'qhat': np.float64(-2.2806737554073333),
#    'coverage': np.float64(0.8855),
#    'efficiency': np.float64(1.0856),
#    'singleton_cov': np.float64(0.952442996742671),
#    'result_str': 'CAL: Coverage: 88.55%, Eff: 1.09, Single: 95.24430%'}),
#  ('K=120, lambda=0.31',
#   {'qhat': np.float64(-2.343639335632324),
#    'coverage': np.float64(0.8821),
#    'efficiency': np.float64(1.0769),
#    'singleton_cov': np.float64(0.9528707199583387),
#    'result_str': 'CAL: Coverage: 88.21%, Eff: 1.08, Single: 95.28707%'}),
#  ('K=120, lambda=0.36',
#   {'qhat': np.float64(-2.403427268266678),
#    'coverage': np.float64(0.8804),
#    'efficiency': np.float64(1.0697),
#    'singleton_cov': np.float64(0.9539020906375796),
#    'result_str': 'CAL: Coverage: 88.04%, Eff: 1.07, Single: 95.39021%'}),
#  ('K=120, lambda=0.41',
#   {'qhat': np.float64(-2.490423957705498),
#    'coverage': np.float64(0.8762),
#    'efficiency': np.float64(1.0567),
#    'singleton_cov': np.float64(0.9545631067961166),
#    'result_str': 'CAL: Coverage: 87.62%, Eff: 1.06, Single: 95.45631%'}),
#  ('K=120, lambda=0.46',
#   {'qhat': np.float64(-2.5665727758407595),
#    'coverage': np.float64(0.8722),
#    'efficiency': np.float64(1.0462),
#    'singleton_cov': np.float64(0.9552624773726403),
#    'result_str': 'CAL: Coverage: 87.22%, Eff: 1.05, Single: 95.52625%'}),
#  ('K=120, lambda=0.51',
#   {'qhat': np.float64(-2.6087062406539916),
#    'coverage': np.float64(0.8696),
#    'efficiency': np.float64(1.0401),
#    'singleton_cov': np.float64(0.955897568546301),
#    'result_str': 'CAL: Coverage: 86.96%, Eff: 1.04, Single: 95.58976%'}),
#  ('K=120, lambda=0.56',
#   {'qhat': np.float64(-2.6955386793613436),
#    'coverage': np.float64(0.8652),
#    'efficiency': np.float64(1.0299),
#    'singleton_cov': np.float64(0.9556014455343315),
#    'result_str': 'CAL: Coverage: 86.52%, Eff: 1.03, Single: 95.56014%'}),
#  ('K=120, lambda=0.61',
#   {'qhat': np.float64(-2.717298142910004),
#    'coverage': np.float64(0.8644),
#    'efficiency': np.float64(1.0268),
#    'singleton_cov': np.float64(0.9555297757153906),
#    'result_str': 'CAL: Coverage: 86.44%, Eff: 1.03, Single: 95.55298%'}),
#  ('K=120, lambda=0.66',
#   {'qhat': np.float64(-2.7797167038917543),
#    'coverage': np.float64(0.8613),
#    'efficiency': np.float64(1.0183),
#    'singleton_cov': np.float64(0.9564657393096342),
#    'result_str': 'CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.64657%'}),
#  ('K=120, lambda=0.71',
#   {'qhat': np.float64(-2.892449898123741),
#    'coverage': np.float64(0.8559),
#    'efficiency': np.float64(1.0045),
#    'singleton_cov': np.float64(0.9568511621933993),
#    'result_str': 'CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.68512%'}),
#  ('K=120, lambda=0.76',
#   {'qhat': np.float64(-2.9924396038055416),
#    'coverage': np.float64(0.8506),
#    'efficiency': np.float64(0.9916),
#    'singleton_cov': np.float64(0.9574249807642985),
#    'result_str': 'CAL: Coverage: 85.06%, Eff: 0.99, Single: 95.74250%'}),
#  ('K=120, lambda=0.81',
#   {'qhat': np.float64(-3.0934919703006747),
#    'coverage': np.float64(0.8457),
#    'efficiency': np.float64(0.9773),
#    'singleton_cov': np.float64(0.9595235045472013),
#    'result_str': 'CAL: Coverage: 84.57%, Eff: 0.98, Single: 95.95235%'}),
#  ('K=120, lambda=0.86',
#   {'qhat': np.float64(-3.2160226249694825),
#    'coverage': np.float64(0.8382),
#    'efficiency': np.float64(0.9601),
#    'singleton_cov': np.float64(0.9602250927228546),
#    'result_str': 'CAL: Coverage: 83.82%, Eff: 0.96, Single: 96.02251%'}),
#  ('K=120, lambda=0.91',
#   {'qhat': np.float64(-3.3398939538002015),
#    'coverage': np.float64(0.8321),
#    'efficiency': np.float64(0.9467),
#    'singleton_cov': np.float64(0.9606238813602659),
#    'result_str': 'CAL: Coverage: 83.21%, Eff: 0.95, Single: 96.06239%'}),
#  ('K=120, lambda=0.96',
#   {'qhat': np.float64(-3.3907285141944885),
#    'coverage': np.float64(0.8293),
#    'efficiency': np.float64(0.9407),
#    'singleton_cov': np.float64(0.9608545477804784),
#    'result_str': 'CAL: Coverage: 82.93%, Eff: 0.94, Single: 96.08545%'}),
#  ('K=140, lambda=0.01',
#   {'qhat': np.float64(-1.8972786724567414),
#    'coverage': np.float64(0.9009),
#    'efficiency': np.float64(1.1351),
#    'singleton_cov': np.float64(0.9497221487165917),
#    'result_str': 'CAL: Coverage: 90.09%, Eff: 1.14, Single: 94.97221%'}),
#  ('K=140, lambda=0.06',
#   {'qhat': np.float64(-1.985589406490326),
#    'coverage': np.float64(0.8972),
#    'efficiency': np.float64(1.1232),
#    'singleton_cov': np.float64(0.9503359241206693),
#    'result_str': 'CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.03359%'}),
#  ('K=140, lambda=0.11',
#   {'qhat': np.float64(-2.079612076282501),
#    'coverage': np.float64(0.8942),
#    'efficiency': np.float64(1.1102),
#    'singleton_cov': np.float64(0.9515579994763027),
#    'result_str': 'CAL: Coverage: 89.42%, Eff: 1.11, Single: 95.15580%'}),
#  ('K=140, lambda=0.16',
#   {'qhat': np.float64(-2.1470189094543457),
#    'coverage': np.float64(0.8922),
#    'efficiency': np.float64(1.1031),
#    'singleton_cov': np.float64(0.9522938178015946),
#    'result_str': 'CAL: Coverage: 89.22%, Eff: 1.10, Single: 95.22938%'}),
#  ('K=140, lambda=0.21',
#   {'qhat': np.float64(-2.2259439897537234),
#    'coverage': np.float64(0.8885),
#    'efficiency': np.float64(1.0929),
#    'singleton_cov': np.float64(0.9515561922125276),
#    'result_str': 'CAL: Coverage: 88.85%, Eff: 1.09, Single: 95.15562%'}),
#  ('K=140, lambda=0.26',
#   {'qhat': np.float64(-2.3055547404289247),
#    'coverage': np.float64(0.8843),
#    'efficiency': np.float64(1.0821),
#    'singleton_cov': np.float64(0.95321866041178),
#    'result_str': 'CAL: Coverage: 88.43%, Eff: 1.08, Single: 95.32187%'}),
#  ('K=140, lambda=0.31',
#   {'qhat': np.float64(-2.3792113399505617),
#    'coverage': np.float64(0.8812),
#    'efficiency': np.float64(1.0723),
#    'singleton_cov': np.float64(0.9537301793605407),
#    'result_str': 'CAL: Coverage: 88.12%, Eff: 1.07, Single: 95.37302%'}),
#  ('K=140, lambda=0.36',
#   {'qhat': np.float64(-2.4728984212875367),
#    'coverage': np.float64(0.8774),
#    'efficiency': np.float64(1.0597),
#    'singleton_cov': np.float64(0.9545336787564767),
#    'result_str': 'CAL: Coverage: 87.74%, Eff: 1.06, Single: 95.45337%'}),
#  ('K=140, lambda=0.41',
#   {'qhat': np.float64(-2.551487798690796),
#    'coverage': np.float64(0.8733),
#    'efficiency': np.float64(1.0482),
#    'singleton_cov': np.float64(0.9551505751583301),
#    'result_str': 'CAL: Coverage: 87.33%, Eff: 1.05, Single: 95.51506%'}),
#  ('K=140, lambda=0.46',
#   {'qhat': np.float64(-2.6205308389663697),
#    'coverage': np.float64(0.8694),
#    'efficiency': np.float64(1.0391),
#    'singleton_cov': np.float64(0.9562855664769788),
#    'result_str': 'CAL: Coverage: 86.94%, Eff: 1.04, Single: 95.62856%'}),
#  ('K=140, lambda=0.51',
#   {'qhat': np.float64(-2.6758528399467467),
#    'coverage': np.float64(0.8664),
#    'efficiency': np.float64(1.0323),
#    'singleton_cov': np.float64(0.9560836993025058),
#    'result_str': 'CAL: Coverage: 86.64%, Eff: 1.03, Single: 95.60837%'}),
#  ('K=140, lambda=0.56',
#   {'qhat': np.float64(-2.7101683664321903),
#    'coverage': np.float64(0.8646),
#    'efficiency': np.float64(1.0278),
#    'singleton_cov': np.float64(0.9552604435275915),
#    'result_str': 'CAL: Coverage: 86.46%, Eff: 1.03, Single: 95.52604%'}),
#  ('K=140, lambda=0.61',
#   {'qhat': np.float64(-2.772307971715927),
#    'coverage': np.float64(0.8618),
#    'efficiency': np.float64(1.0196),
#    'singleton_cov': np.float64(0.9563369397217929),
#    'result_str': 'CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63369%'}),
#  ('K=140, lambda=0.66',
#   {'qhat': np.float64(-2.8523643589019776),
#    'coverage': np.float64(0.8579),
#    'efficiency': np.float64(1.0097),
#    'singleton_cov': np.float64(0.9562034420755202),
#    'result_str': 'CAL: Coverage: 85.79%, Eff: 1.01, Single: 95.62034%'}),
#  ('K=140, lambda=0.71',
#   {'qhat': np.float64(-2.9493459463119507),
#    'coverage': np.float64(0.8525),
#    'efficiency': np.float64(0.9972),
#    'singleton_cov': np.float64(0.9567394094993582),
#    'result_str': 'CAL: Coverage: 85.25%, Eff: 1.00, Single: 95.67394%'}),
#  ('K=140, lambda=0.76',
#   {'qhat': np.float64(-3.036146795153618),
#    'coverage': np.float64(0.8488),
#    'efficiency': np.float64(0.9863),
#    'singleton_cov': np.float64(0.9583333333333334),
#    'result_str': 'CAL: Coverage: 84.88%, Eff: 0.99, Single: 95.83333%'}),
#  ('K=140, lambda=0.81',
#   {'qhat': np.float64(-3.1217100918293),
#    'coverage': np.float64(0.8444),
#    'efficiency': np.float64(0.9741),
#    'singleton_cov': np.float64(0.9593194320071639),
#    'result_str': 'CAL: Coverage: 84.44%, Eff: 0.97, Single: 95.93194%'}),
#  ('K=140, lambda=0.86',
#   {'qhat': np.float64(-3.2054973033815624),
#    'coverage': np.float64(0.8386),
#    'efficiency': np.float64(0.9615),
#    'singleton_cov': np.float64(0.9599590635793783),
#    'result_str': 'CAL: Coverage: 83.86%, Eff: 0.96, Single: 95.99591%'}),
#  ('K=140, lambda=0.91',
#   {'qhat': np.float64(-3.2671453881263735),
#    'coverage': np.float64(0.836),
#    'efficiency': np.float64(0.9548),
#    'singleton_cov': np.float64(0.9603783231083844),
#    'result_str': 'CAL: Coverage: 83.60%, Eff: 0.95, Single: 96.03783%'}),
#  ('K=140, lambda=0.96',
#   {'qhat': np.float64(-3.360359891951084),
#    'coverage': np.float64(0.8306),
#    'efficiency': np.float64(0.9438),
#    'singleton_cov': np.float64(0.9607165706973768),
#    'result_str': 'CAL: Coverage: 83.06%, Eff: 0.94, Single: 96.07166%'}),
#  ('K=160, lambda=0.01',
#   {'qhat': np.float64(-1.8885816049575805),
#    'coverage': np.float64(0.9014),
#    'efficiency': np.float64(1.1364),
#    'singleton_cov': np.float64(0.9494708994708995),
#    'result_str': 'CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94709%'}),
#  ('K=160, lambda=0.06',
#   {'qhat': np.float64(-1.9662070226669313),
#    'coverage': np.float64(0.898),
#    'efficiency': np.float64(1.1253),
#    'singleton_cov': np.float64(0.9503097403453276),
#    'result_str': 'CAL: Coverage: 89.80%, Eff: 1.13, Single: 95.03097%'}),
#  ('K=160, lambda=0.11',
#   {'qhat': np.float64(-2.0465987491607667),
#    'coverage': np.float64(0.8954),
#    'efficiency': np.float64(1.1147),
#    'singleton_cov': np.float64(0.9513187245768272),
#    'result_str': 'CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13187%'}),
#  ('K=160, lambda=0.16',
#   {'qhat': np.float64(-2.0983531284332275),
#    'coverage': np.float64(0.8937),
#    'efficiency': np.float64(1.1083),
#    'singleton_cov': np.float64(0.9519633507853403),
#    'result_str': 'CAL: Coverage: 89.37%, Eff: 1.11, Single: 95.19634%'}),
#  ('K=160, lambda=0.21',
#   {'qhat': np.float64(-2.14923176407814),
#    'coverage': np.float64(0.8921),
#    'efficiency': np.float64(1.1029),
#    'singleton_cov': np.float64(0.9522938178015946),
#    'result_str': 'CAL: Coverage: 89.21%, Eff: 1.10, Single: 95.22938%'}),
#  ('K=160, lambda=0.26',
#   {'qhat': np.float64(-2.2394895839691165),
#    'coverage': np.float64(0.8879),
#    'efficiency': np.float64(1.0919),
#    'singleton_cov': np.float64(0.9516612377850163),
#    'result_str': 'CAL: Coverage: 88.79%, Eff: 1.09, Single: 95.16612%'}),
#  ('K=160, lambda=0.31',
#   {'qhat': np.float64(-2.313226089477539),
#    'coverage': np.float64(0.8838),
#    'efficiency': np.float64(1.0811),
#    'singleton_cov': np.float64(0.9533307261113284),
#    'result_str': 'CAL: Coverage: 88.38%, Eff: 1.08, Single: 95.33307%'}),
#  ('K=160, lambda=0.36',
#   {'qhat': np.float64(-2.360462965965271),
#    'coverage': np.float64(0.8816),
#    'efficiency': np.float64(1.0744),
#    'singleton_cov': np.float64(0.9534278652270066),
#    'result_str': 'CAL: Coverage: 88.16%, Eff: 1.07, Single: 95.34279%'}),
#  ('K=160, lambda=0.41',
#   {'qhat': np.float64(-2.412988877296448),
#    'coverage': np.float64(0.8801),
#    'efficiency': np.float64(1.0678),
#    'singleton_cov': np.float64(0.9542153047989624),
#    'result_str': 'CAL: Coverage: 88.01%, Eff: 1.07, Single: 95.42153%'}),
#  ('K=160, lambda=0.46',
#   {'qhat': np.float64(-2.479444713592529),
#    'coverage': np.float64(0.877),
#    'efficiency': np.float64(1.0587),
#    'singleton_cov': np.float64(0.9543101216670982),
#    'result_str': 'CAL: Coverage: 87.70%, Eff: 1.06, Single: 95.43101%'}),
#  ('K=160, lambda=0.51',
#   {'qhat': np.float64(-2.522085704803467),
#    'coverage': np.float64(0.8748),
#    'efficiency': np.float64(1.0526),
#    'singleton_cov': np.float64(0.9547452805792604),
#    'result_str': 'CAL: Coverage: 87.48%, Eff: 1.05, Single: 95.47453%'}),
#  ('K=160, lambda=0.56',
#   {'qhat': np.float64(-2.5611421537399295),
#    'coverage': np.float64(0.8728),
#    'efficiency': np.float64(1.0472),
#    'singleton_cov': np.float64(0.9552682611506141),
#    'result_str': 'CAL: Coverage: 87.28%, Eff: 1.05, Single: 95.52683%'}),
#  ('K=160, lambda=0.61',
#   {'qhat': np.float64(-2.5933479380607602),
#    'coverage': np.float64(0.8704),
#    'efficiency': np.float64(1.0428),
#    'singleton_cov': np.float64(0.9555987055016181),
#    'result_str': 'CAL: Coverage: 87.04%, Eff: 1.04, Single: 95.55987%'}),
#  ('K=160, lambda=0.66',
#   {'qhat': np.float64(-2.6286091017723083),
#    'coverage': np.float64(0.8691),
#    'efficiency': np.float64(1.0384),
#    'singleton_cov': np.float64(0.956167571761055),
#    'result_str': 'CAL: Coverage: 86.91%, Eff: 1.04, Single: 95.61676%'}),
#  ('K=160, lambda=0.71',
#   {'qhat': np.float64(-2.681953480243683),
#    'coverage': np.float64(0.8659),
#    'efficiency': np.float64(1.0315),
#    'singleton_cov': np.float64(0.9559545337122191),
#    'result_str': 'CAL: Coverage: 86.59%, Eff: 1.03, Single: 95.59545%'}),
#  ('K=160, lambda=0.76',
#   {'qhat': np.float64(-2.7441147279739377),
#    'coverage': np.float64(0.8624),
#    'efficiency': np.float64(1.0223),
#    'singleton_cov': np.float64(0.955664389740946),
#    'result_str': 'CAL: Coverage: 86.24%, Eff: 1.02, Single: 95.56644%'}),
#  ('K=160, lambda=0.81',
#   {'qhat': np.float64(-2.773515870627016),
#    'coverage': np.float64(0.8617),
#    'efficiency': np.float64(1.0193),
#    'singleton_cov': np.float64(0.9562250547186816),
#    'result_str': 'CAL: Coverage: 86.17%, Eff: 1.02, Single: 95.62251%'}),
#  ('K=160, lambda=0.86',
#   {'qhat': np.float64(-2.752103569507599),
#    'coverage': np.float64(0.8622),
#    'efficiency': np.float64(1.0215),
#    'singleton_cov': np.float64(0.9561573178594455),
#    'result_str': 'CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.61573%'}),
#  ('K=160, lambda=0.91',
#   {'qhat': np.float64(-2.748209819793701),
#    'coverage': np.float64(0.8622),
#    'efficiency': np.float64(1.0219),
#    'singleton_cov': np.float64(0.955664389740946),
#    'result_str': 'CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.56644%'}),
#  ('K=160, lambda=0.96',
#   {'qhat': np.float64(-2.7419634574651717),
#    'coverage': np.float64(0.8625),
#    'efficiency': np.float64(1.0225),
#    'singleton_cov': np.float64(0.955664389740946),
#    'result_str': 'CAL: Coverage: 86.25%, Eff: 1.02, Single: 95.56644%'}),
#  ('K=180, lambda=0.01',
#   {'qhat': np.float64(-1.8816485214233398),
#    'coverage': np.float64(0.9015),
#    'efficiency': np.float64(1.1369),
#    'singleton_cov': np.float64(0.9495965074745336),
#    'result_str': 'CAL: Coverage: 90.15%, Eff: 1.14, Single: 94.95965%'}),
#  ('K=180, lambda=0.06',
#   {'qhat': np.float64(-1.9494049263000488),
#    'coverage': np.float64(0.8989),
#    'efficiency': np.float64(1.1277),
#    'singleton_cov': np.float64(0.950151655017803),
#    'result_str': 'CAL: Coverage: 89.89%, Eff: 1.13, Single: 95.01517%'}),
#  ('K=180, lambda=0.11',
#   {'qhat': np.float64(-2.0436054968833925),
#    'coverage': np.float64(0.8956),
#    'efficiency': np.float64(1.1153),
#    'singleton_cov': np.float64(0.9513059456621604),
#    'result_str': 'CAL: Coverage: 89.56%, Eff: 1.12, Single: 95.13059%'}),
#  ('K=180, lambda=0.16',
#   {'qhat': np.float64(-2.1130588054656982),
#    'coverage': np.float64(0.8931),
#    'efficiency': np.float64(1.1067),
#    'singleton_cov': np.float64(0.9519884877027734),
#    'result_str': 'CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.19885%'}),
#  ('K=180, lambda=0.21',
#   {'qhat': np.float64(-2.148295006752014),
#    'coverage': np.float64(0.8921),
#    'efficiency': np.float64(1.1029),
#    'singleton_cov': np.float64(0.9522938178015946),
#    'result_str': 'CAL: Coverage: 89.21%, Eff: 1.10, Single: 95.22938%'}),
#  ('K=180, lambda=0.26',
#   {'qhat': np.float64(-2.2133802556991578),
#    'coverage': np.float64(0.8893),
#    'efficiency': np.float64(1.0953),
#    'singleton_cov': np.float64(0.9515056707078607),
#    'result_str': 'CAL: Coverage: 88.93%, Eff: 1.10, Single: 95.15057%'}),
#  ('K=180, lambda=0.31',
#   {'qhat': np.float64(-2.268649423122406),
#    'coverage': np.float64(0.8862),
#    'efficiency': np.float64(1.0876),
#    'singleton_cov': np.float64(0.9521886399166233),
#    'result_str': 'CAL: Coverage: 88.62%, Eff: 1.09, Single: 95.21886%'}),
#  ('K=180, lambda=0.36',
#   {'qhat': np.float64(-2.3343526554107665),
#    'coverage': np.float64(0.8831),
#    'efficiency': np.float64(1.0787),
#    'singleton_cov': np.float64(0.9532552083333333),
#    'result_str': 'CAL: Coverage: 88.31%, Eff: 1.08, Single: 95.32552%'}),
#  ('K=180, lambda=0.41',
#   {'qhat': np.float64(-2.396060713529587),
#    'coverage': np.float64(0.8807),
#    'efficiency': np.float64(1.0707),
#    'singleton_cov': np.float64(0.9538781343380538),
#    'result_str': 'CAL: Coverage: 88.07%, Eff: 1.07, Single: 95.38781%'}),
#  ('K=180, lambda=0.46',
#   {'qhat': np.float64(-2.4428885436058043),
#    'coverage': np.float64(0.8782),
#    'efficiency': np.float64(1.0635),
#    'singleton_cov': np.float64(0.954197482807837),
#    'result_str': 'CAL: Coverage: 87.82%, Eff: 1.06, Single: 95.41975%'}),
#  ('K=180, lambda=0.51',
#   {'qhat': np.float64(-2.4919128441810607),
#    'coverage': np.float64(0.8762),
#    'efficiency': np.float64(1.0566),
#    'singleton_cov': np.float64(0.9545689878332901),
#    'result_str': 'CAL: Coverage: 87.62%, Eff: 1.06, Single: 95.45690%'}),
#  ('K=180, lambda=0.56',
#   {'qhat': np.float64(-2.5318693161010746),
#    'coverage': np.float64(0.8746),
#    'efficiency': np.float64(1.0513),
#    'singleton_cov': np.float64(0.9550213260953858),
#    'result_str': 'CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.50213%'}),
#  ('K=180, lambda=0.61',
#   {'qhat': np.float64(-2.578312985897064),
#    'coverage': np.float64(0.8712),
#    'efficiency': np.float64(1.0446),
#    'singleton_cov': np.float64(0.9552393272962484),
#    'result_str': 'CAL: Coverage: 87.12%, Eff: 1.04, Single: 95.52393%'}),
#  ('K=180, lambda=0.66',
#   {'qhat': np.float64(-2.6355609178543093),
#    'coverage': np.float64(0.8688),
#    'efficiency': np.float64(1.0377),
#    'singleton_cov': np.float64(0.956167571761055),
#    'result_str': 'CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.61676%'}),
#  ('K=180, lambda=0.71',
#   {'qhat': np.float64(-2.6609845250844955),
#    'coverage': np.float64(0.8675),
#    'efficiency': np.float64(1.0343),
#    'singleton_cov': np.float64(0.956095041322314),
#    'result_str': 'CAL: Coverage: 86.75%, Eff: 1.03, Single: 95.60950%'}),
#  ('K=180, lambda=0.76',
#   {'qhat': np.float64(-2.707538013458252),
#    'coverage': np.float64(0.8648),
#    'efficiency': np.float64(1.0283),
#    'singleton_cov': np.float64(0.9553778694867165),
#    'result_str': 'CAL: Coverage: 86.48%, Eff: 1.03, Single: 95.53779%'}),
#  ('K=180, lambda=0.81',
#   {'qhat': np.float64(-2.715748932361603),
#    'coverage': np.float64(0.8644),
#    'efficiency': np.float64(1.0268),
#    'singleton_cov': np.float64(0.9555297757153906),
#    'result_str': 'CAL: Coverage: 86.44%, Eff: 1.03, Single: 95.55298%'}),
#  ('K=180, lambda=0.86',
#   {'qhat': np.float64(-2.7343869471549986),
#    'coverage': np.float64(0.8628),
#    'efficiency': np.float64(1.0235),
#    'singleton_cov': np.float64(0.9554066245650212),
#    'result_str': 'CAL: Coverage: 86.28%, Eff: 1.02, Single: 95.54066%'}),
#  ('K=180, lambda=0.91',
#   {'qhat': np.float64(-2.758385295122862),
#    'coverage': np.float64(0.862),
#    'efficiency': np.float64(1.0205),
#    'singleton_cov': np.float64(0.9560736828545665),
#    'result_str': 'CAL: Coverage: 86.20%, Eff: 1.02, Single: 95.60737%'}),
#  ('K=180, lambda=0.96',
#   {'qhat': np.float64(-2.7270335280895233),
#    'coverage': np.float64(0.8632),
#    'efficiency': np.float64(1.0249),
#    'singleton_cov': np.float64(0.9551488593890965),
#    'result_str': 'CAL: Coverage: 86.32%, Eff: 1.02, Single: 95.51489%'}),
#  ('K=200, lambda=0.01',
#   {'qhat': np.float64(-1.8875775885581971),
#    'coverage': np.float64(0.9014),
#    'efficiency': np.float64(1.1364),
#    'singleton_cov': np.float64(0.9494708994708995),
#    'result_str': 'CAL: Coverage: 90.14%, Eff: 1.14, Single: 94.94709%'}),
#  ('K=200, lambda=0.06',
#   {'qhat': np.float64(-1.9499384546279908),
#    'coverage': np.float64(0.8987),
#    'efficiency': np.float64(1.1275),
#    'singleton_cov': np.float64(0.9501385041551247),
#    'result_str': 'CAL: Coverage: 89.87%, Eff: 1.13, Single: 95.01385%'}),
#  ('K=200, lambda=0.11',
#   {'qhat': np.float64(-2.0395541203022005),
#    'coverage': np.float64(0.8959),
#    'efficiency': np.float64(1.1161),
#    'singleton_cov': np.float64(0.9514116874589625),
#    'result_str': 'CAL: Coverage: 89.59%, Eff: 1.12, Single: 95.14117%'}),
#  ('K=200, lambda=0.16',
#   {'qhat': np.float64(-2.128803029060364),
#    'coverage': np.float64(0.8928),
#    'efficiency': np.float64(1.1049),
#    'singleton_cov': np.float64(0.9522813439665315),
#    'result_str': 'CAL: Coverage: 89.28%, Eff: 1.10, Single: 95.22813%'}),
#  ('K=200, lambda=0.21',
#   {'qhat': np.float64(-2.186340022087097),
#    'coverage': np.float64(0.8905),
#    'efficiency': np.float64(1.0988),
#    'singleton_cov': np.float64(0.9517034329721968),
#    'result_str': 'CAL: Coverage: 89.05%, Eff: 1.10, Single: 95.17034%'}),
#  ('K=200, lambda=0.26',
#   {'qhat': np.float64(-2.247212381362915),
#    'coverage': np.float64(0.8878),
#    'efficiency': np.float64(1.091),
#    'singleton_cov': np.float64(0.95217617930675),
#    'result_str': 'CAL: Coverage: 88.78%, Eff: 1.09, Single: 95.21762%'}),
#  ('K=200, lambda=0.31',
#   {'qhat': np.float64(-2.3120487570762633),
#    'coverage': np.float64(0.8838),
#    'efficiency': np.float64(1.0812),
#    'singleton_cov': np.float64(0.9533246414602347),
#    'result_str': 'CAL: Coverage: 88.38%, Eff: 1.08, Single: 95.33246%'}),
#  ('K=200, lambda=0.36',
#   {'qhat': np.float64(-2.386224555969238),
#    'coverage': np.float64(0.881),
#    'efficiency': np.float64(1.0717),
#    'singleton_cov': np.float64(0.9538601507668313),
#    'result_str': 'CAL: Coverage: 88.10%, Eff: 1.07, Single: 95.38602%'}),
#  ('K=200, lambda=0.41',
#   {'qhat': np.float64(-2.464982209205627),
#    'coverage': np.float64(0.8777),
#    'efficiency': np.float64(1.0612),
#    'singleton_cov': np.float64(0.9543745949449125),
#    'result_str': 'CAL: Coverage: 87.77%, Eff: 1.06, Single: 95.43746%'}),
#  ('K=200, lambda=0.46',
#   {'qhat': np.float64(-2.508162970542908),
#    'coverage': np.float64(0.8753),
#    'efficiency': np.float64(1.0537),
#    'singleton_cov': np.float64(0.9547394284236389),
#    'result_str': 'CAL: Coverage: 87.53%, Eff: 1.05, Single: 95.47394%'}),
#  ('K=200, lambda=0.51',
#   {'qhat': np.float64(-2.5754561185836793),
#    'coverage': np.float64(0.8714),
#    'efficiency': np.float64(1.0451),
#    'singleton_cov': np.float64(0.9553513653423062),
#    'result_str': 'CAL: Coverage: 87.14%, Eff: 1.05, Single: 95.53514%'}),
#  ('K=200, lambda=0.56',
#   {'qhat': np.float64(-2.6645889091491703),
#    'coverage': np.float64(0.8672),
#    'efficiency': np.float64(1.0337),
#    'singleton_cov': np.float64(0.955977278595404),
#    'result_str': 'CAL: Coverage: 86.72%, Eff: 1.03, Single: 95.59773%'}),
#  ('K=200, lambda=0.61',
#   {'qhat': np.float64(-2.7294859957695006),
#    'coverage': np.float64(0.8631),
#    'efficiency': np.float64(1.0246),
#    'singleton_cov': np.float64(0.9552719773137407),
#    'result_str': 'CAL: Coverage: 86.31%, Eff: 1.02, Single: 95.52720%'}),
#  ('K=200, lambda=0.66',
#   {'qhat': np.float64(-2.7790720868110657),
#    'coverage': np.float64(0.8613),
#    'efficiency': np.float64(1.0186),
#    'singleton_cov': np.float64(0.9563369397217929),
#    'result_str': 'CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.63369%'}),
#  ('K=200, lambda=0.71',
#   {'qhat': np.float64(-2.8668317091464997),
#    'coverage': np.float64(0.8575),
#    'efficiency': np.float64(1.0087),
#    'singleton_cov': np.float64(0.9564491264131552),
#    'result_str': 'CAL: Coverage: 85.75%, Eff: 1.01, Single: 95.64491%'}),
#  ('K=200, lambda=0.76',
#   {'qhat': np.float64(-2.923249191045761),
#    'coverage': np.float64(0.8543),
#    'efficiency': np.float64(1.0011),
#    'singleton_cov': np.float64(0.9567227430332605),
#    'result_str': 'CAL: Coverage: 85.43%, Eff: 1.00, Single: 95.67227%'}),
#  ('K=200, lambda=0.81',
#   {'qhat': np.float64(-3.0025155019760135),
#    'coverage': np.float64(0.8502),
#    'efficiency': np.float64(0.99),
#    'singleton_cov': np.float64(0.9577031530376826),
#    'result_str': 'CAL: Coverage: 85.02%, Eff: 0.99, Single: 95.77032%'}),
#  ('K=200, lambda=0.86',
#   {'qhat': np.float64(-3.0287138828635216),
#    'coverage': np.float64(0.8491),
#    'efficiency': np.float64(0.9873),
#    'singleton_cov': np.float64(0.958076923076923),
#    'result_str': 'CAL: Coverage: 84.91%, Eff: 0.99, Single: 95.80769%'}),
#  ('K=200, lambda=0.91',
#   {'qhat': np.float64(-3.0556766974925997),
#    'coverage': np.float64(0.8481),
#    'efficiency': np.float64(0.9832),
#    'singleton_cov': np.float64(0.958407985666752),
#    'result_str': 'CAL: Coverage: 84.81%, Eff: 0.98, Single: 95.84080%'}),
#  ('K=200, lambda=0.96',
#   {'qhat': np.float64(-3.0415355681069194),
#    'coverage': np.float64(0.8486),
#    'efficiency': np.float64(0.9855),
#    'singleton_cov': np.float64(0.9582265504869297),
#    'result_str': 'CAL: Coverage: 84.86%, Eff: 0.99, Single: 95.82266%'})]

# %%
import re

plot_data_clustering = {}   

for label, metrics in clustering_results_global:
    if label == "BASELINE":
        K = "BASELINE"
        lam = None
    else:
        match = re.match(r"K=(\d+), lambda=([0-9.]+)", label)
        if match:
            K = int(match.group(1))
            lam = float(match.group(2))
        else:
            continue

    if K not in plot_data_clustering:
        plot_data_clustering[K] = {"lambda": [], "coverage": [], "efficiency": [],
                        "singleton_cov": [], "qhat": []}

    # Append values
    plot_data_clustering[K]["lambda"].append(lam)
    plot_data_clustering[K]["coverage"].append(float(metrics["coverage"]))
    plot_data_clustering[K]["efficiency"].append(float(metrics["efficiency"]))
    plot_data_clustering[K]["singleton_cov"].append(float(metrics["singleton_cov"]))
    plot_data_clustering[K]["qhat"].append(float(metrics["qhat"]))

# %%
plot_data_clustering
# Out:
# {'BASELINE': {'lambda': [None],
#   'coverage': [0.9016],
#   'efficiency': [1.1376],
#   'singleton_cov': [0.9496955255493779],
#   'qhat': [-1.8755414485931396]},
#  20: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9004,
#    0.8944,
#    0.8886,
#    0.882,
#    0.876,
#    0.8688,
#    0.8605,
#    0.8546,
#    0.849,
#    0.8425,
#    0.8368,
#    0.8314,
#    0.8263,
#    0.8204,
#    0.8168,
#    0.8143,
#    0.8116,
#    0.8099,
#    0.8092,
#    0.803],
#   'efficiency': [1.1332,
#    1.1115,
#    1.0936,
#    1.0762,
#    1.0558,
#    1.0376,
#    1.0158,
#    1.0017,
#    0.9869,
#    0.9705,
#    0.9558,
#    0.9453,
#    0.9361,
#    0.9251,
#    0.9189,
#    0.9141,
#    0.9098,
#    0.9069,
#    0.9057,
#    0.893],
#   'singleton_cov': [0.9498876107364802,
#    0.9516255899318301,
#    0.9512893982808023,
#    0.9532552083333333,
#    0.9547042836806005,
#    0.9562912194491142,
#    0.9565217391304348,
#    0.956728299948639,
#    0.9582051282051282,
#    0.959191505692721,
#    0.9605263157894737,
#    0.9604859335038363,
#    0.9606611993849308,
#    0.9608371854134566,
#    0.9614988411022405,
#    0.9612512873326468,
#    0.9611863313990974,
#    0.9613994319648851,
#    0.9617472215042646,
#    0.9635349078640021],
#   'qhat': [-1.9079369115829468,
#    -2.068760538101196,
#    -2.2221137428283693,
#    -2.3488946199417113,
#    -2.496129536628723,
#    -2.637170186042786,
#    -2.8010596895217894,
#    -2.9152576327323914,
#    -3.0343485736846922,
#    -3.1429221987724305,
#    -3.2542052173614504,
#    -3.3489245796203617,
#    -3.4285229229927063,
#    -3.52413519859314,
#    -3.584357657432556,
#    -3.631246918439865,
#    -3.674091997146607,
#    -3.7067468309402467,
#    -3.7232253217697147,
#    -3.844489388456568]},
#  40: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9004,
#    0.8968,
#    0.8937,
#    0.8893,
#    0.8847,
#    0.8808,
#    0.8777,
#    0.8742,
#    0.8695,
#    0.8651,
#    0.8619,
#    0.8592,
#    0.8575,
#    0.8559,
#    0.8541,
#    0.8527,
#    0.8509,
#    0.8513,
#    0.8519,
#    0.8512],
#   'efficiency': [1.1335,
#    1.1219,
#    1.1087,
#    1.0953,
#    1.0835,
#    1.0713,
#    1.0611,
#    1.0506,
#    1.0396,
#    1.0295,
#    1.0202,
#    1.0128,
#    1.0087,
#    1.0048,
#    1.0008,
#    0.9975,
#    0.9929,
#    0.994,
#    0.9958,
#    0.9937],
#   'singleton_cov': [0.9498743552440153,
#    0.9503686150605581,
#    0.9517015706806282,
#    0.9515056707078607,
#    0.9528277299973938,
#    0.9537422037422038,
#    0.9543805080352514,
#    0.9552509053285049,
#    0.956150562669771,
#    0.9556014455343315,
#    0.9561968564802886,
#    0.9562925825941637,
#    0.9564491264131552,
#    0.9567171846904701,
#    0.9568345323741008,
#    0.9567449621357977,
#    0.9572693442833312,
#    0.957135523613963,
#    0.9568677792041078,
#    0.9571410239958937],
#   'qhat': [-1.9066819620132447,
#    -1.994558711051941,
#    -2.095846428871155,
#    -2.21197699546814,
#    -2.2971434450149535,
#    -2.3917815828323366,
#    -2.466695499420166,
#    -2.5364651370048525,
#    -2.6123566579818727,
#    -2.6991270565986634,
#    -2.761444284915924,
#    -2.824061651229859,
#    -2.8662472319602967,
#    -2.891396281719208,
#    -2.926312572956085,
#    -2.9458134603500366,
#    -2.977254409790039,
#    -2.9690654528141023,
#    -2.958465875387192,
#    -2.971397809386253]},
#  60: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9014,
#    0.8979,
#    0.8944,
#    0.8908,
#    0.8884,
#    0.8843,
#    0.8809,
#    0.8776,
#    0.8748,
#    0.8708,
#    0.8689,
#    0.865,
#    0.8622,
#    0.8618,
#    0.8618,
#    0.8613,
#    0.8618,
#    0.8608,
#    0.8582,
#    0.854],
#   'efficiency': [1.1363,
#    1.125,
#    1.1111,
#    1.0995,
#    1.0925,
#    1.0821,
#    1.0715,
#    1.0607,
#    1.0527,
#    1.0436,
#    1.0379,
#    1.0294,
#    1.0218,
#    1.0197,
#    1.0197,
#    1.0183,
#    1.0197,
#    1.0167,
#    1.0103,
#    1.0005],
#   'singleton_cov': [0.9494775823303796,
#    0.9503162888771745,
#    0.9516509433962265,
#    0.9517034329721968,
#    0.9516864175022789,
#    0.95321866041178,
#    0.9537422037422038,
#    0.9542746113989637,
#    0.9547394284236389,
#    0.9556044524980585,
#    0.956167571761055,
#    0.9554781262098335,
#    0.9557875741170405,
#    0.9563313152131908,
#    0.9563313152131908,
#    0.9564657393096342,
#    0.9563313152131908,
#    0.9563874951756078,
#    0.9563206577595067,
#    0.9569574714120519],
#   'qhat': [-1.889088921546936,
#    -1.9699340534210206,
#    -2.071489496231079,
#    -2.1764060926437376,
#    -2.2319846212863923,
#    -2.304733352661133,
#    -2.38933963060379,
#    -2.468384122848511,
#    -2.518627478480339,
#    -2.587878115177155,
#    -2.6327837896347046,
#    -2.7016829013824464,
#    -2.749038344621658,
#    -2.769514389038086,
#    -2.766695349216461,
#    -2.7810178565979005,
#    -2.7675258469581605,
#    -2.7922335016727446,
#    -2.8478606480360034,
#    -2.9272949698567388]},
#  80: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.901,
#    0.8975,
#    0.8946,
#    0.8915,
#    0.8883,
#    0.8841,
#    0.8818,
#    0.8785,
#    0.8764,
#    0.872,
#    0.8688,
#    0.865,
#    0.8618,
#    0.8591,
#    0.855,
#    0.8504,
#    0.8483,
#    0.8405,
#    0.835,
#    0.8297],
#   'efficiency': [1.1356,
#    1.1242,
#    1.1123,
#    1.1012,
#    1.0924,
#    1.0817,
#    1.0755,
#    1.0646,
#    1.057,
#    1.0459,
#    1.0375,
#    1.0293,
#    1.0199,
#    1.0123,
#    1.0022,
#    0.9911,
#    0.9842,
#    0.9668,
#    0.9523,
#    0.9414],
#   'singleton_cov': [0.9494708994708995,
#    0.9503162888771745,
#    0.9511268343815513,
#    0.9523000522739153,
#    0.9516801250325606,
#    0.9533368091762252,
#    0.9533975527206456,
#    0.954185593770279,
#    0.9545689878332901,
#    0.9553744664338378,
#    0.9562968709594001,
#    0.9554838709677419,
#    0.9562024990338787,
#    0.956426735218509,
#    0.9568622416228014,
#    0.9574304397999743,
#    0.9584934665641814,
#    0.9592933947772657,
#    0.9606389776357828,
#    0.9608595548733692],
#   'qhat': [-1.8924807620048523,
#    -1.9771774482727051,
#    -2.061874134540558,
#    -2.1640256309509276,
#    -2.234134931564331,
#    -2.309373304843903,
#    -2.355426063537598,
#    -2.4371138620376587,
#    -2.4889448678493498,
#    -2.571519045829773,
#    -2.637892800346017,
#    -2.7028948867321017,
#    -2.765281205177307,
#    -2.828517942428589,
#    -2.9118370103836058,
#    -2.996711688041687,
#    -3.050139914751053,
#    -3.1729897817969324,
#    -3.2945300179719927,
#    -3.3861773911118505]},
#  100: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9009,
#    0.8972,
#    0.8947,
#    0.8925,
#    0.8887,
#    0.8841,
#    0.8804,
#    0.8772,
#    0.8716,
#    0.869,
#    0.8651,
#    0.8618,
#    0.8585,
#    0.8559,
#    0.8527,
#    0.8516,
#    0.8504,
#    0.8493,
#    0.849,
#    0.8471],
#   'efficiency': [1.1351,
#    1.1233,
#    1.1126,
#    1.1039,
#    1.0937,
#    1.0817,
#    1.0698,
#    1.0592,
#    1.0454,
#    1.0381,
#    1.0298,
#    1.0199,
#    1.011,
#    1.0045,
#    0.9975,
#    0.9949,
#    0.9911,
#    0.9879,
#    0.987,
#    0.9803],
#   'singleton_cov': [0.9497221487165917,
#    0.9502107481559536,
#    0.9511204298257109,
#    0.9521631159325579,
#    0.9512957416330251,
#    0.9533368091762252,
#    0.953778239418333,
#    0.9544218567914023,
#    0.9554750194149625,
#    0.9561732385261797,
#    0.9555957144701175,
#    0.9562024990338787,
#    0.9563150456122318,
#    0.9568511621933993,
#    0.9567449621357977,
#    0.9571190139940943,
#    0.9574304397999743,
#    0.957959497564727,
#    0.9581997692011797,
#    0.959513132607303],
#   'qhat': [-1.8968845653533934,
#    -1.983797311782837,
#    -2.059904491752386,
#    -2.140814714431763,
#    -2.2187856912612913,
#    -2.3096409726142886,
#    -2.403342831134796,
#    -2.4764360475540164,
#    -2.5725783371925353,
#    -2.6311361408233642,
#    -2.696843341588974,
#    -2.765207133293152,
#    -2.8402328610420224,
#    -2.8929926681518556,
#    -2.9464170336723328,
#    -2.9628789901733397,
#    -2.997051839828491,
#    -3.020568698644638,
#    -3.033097743988037,
#    -3.073627680540085]},
#  120: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9009,
#    0.8976,
#    0.8954,
#    0.8919,
#    0.89,
#    0.8855,
#    0.8821,
#    0.8804,
#    0.8762,
#    0.8722,
#    0.8696,
#    0.8652,
#    0.8644,
#    0.8613,
#    0.8559,
#    0.8506,
#    0.8457,
#    0.8382,
#    0.8321,
#    0.8293],
#   'efficiency': [1.1353,
#    1.1243,
#    1.1145,
#    1.1024,
#    1.0973,
#    1.0856,
#    1.0769,
#    1.0697,
#    1.0567,
#    1.0462,
#    1.0401,
#    1.0299,
#    1.0268,
#    1.0183,
#    1.0045,
#    0.9916,
#    0.9773,
#    0.9601,
#    0.9467,
#    0.9407],
#   'singleton_cov': [0.949715495567024,
#    0.9504415447475946,
#    0.9513314967860422,
#    0.9522938178015946,
#    0.9516044873467258,
#    0.952442996742671,
#    0.9528707199583387,
#    0.9539020906375796,
#    0.9545631067961166,
#    0.9552624773726403,
#    0.955897568546301,
#    0.9556014455343315,
#    0.9555297757153906,
#    0.9564657393096342,
#    0.9568511621933993,
#    0.9574249807642985,
#    0.9595235045472013,
#    0.9602250927228546,
#    0.9606238813602659,
#    0.9608545477804784],
#   'qhat': [-1.8950761032104493,
#    -1.976497368812561,
#    -2.049767937660217,
#    -2.153371982574463,
#    -2.197789678573608,
#    -2.2806737554073333,
#    -2.343639335632324,
#    -2.403427268266678,
#    -2.490423957705498,
#    -2.5665727758407595,
#    -2.6087062406539916,
#    -2.6955386793613436,
#    -2.717298142910004,
#    -2.7797167038917543,
#    -2.892449898123741,
#    -2.9924396038055416,
#    -3.0934919703006747,
#    -3.2160226249694825,
#    -3.3398939538002015,
#    -3.3907285141944885]},
#  140: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9009,
#    0.8972,
#    0.8942,
#    0.8922,
#    0.8885,
#    0.8843,
#    0.8812,
#    0.8774,
#    0.8733,
#    0.8694,
#    0.8664,
#    0.8646,
#    0.8618,
#    0.8579,
#    0.8525,
#    0.8488,
#    0.8444,
#    0.8386,
#    0.836,
#    0.8306],
#   'efficiency': [1.1351,
#    1.1232,
#    1.1102,
#    1.1031,
#    1.0929,
#    1.0821,
#    1.0723,
#    1.0597,
#    1.0482,
#    1.0391,
#    1.0323,
#    1.0278,
#    1.0196,
#    1.0097,
#    0.9972,
#    0.9863,
#    0.9741,
#    0.9615,
#    0.9548,
#    0.9438],
#   'singleton_cov': [0.9497221487165917,
#    0.9503359241206693,
#    0.9515579994763027,
#    0.9522938178015946,
#    0.9515561922125276,
#    0.95321866041178,
#    0.9537301793605407,
#    0.9545336787564767,
#    0.9551505751583301,
#    0.9562855664769788,
#    0.9560836993025058,
#    0.9552604435275915,
#    0.9563369397217929,
#    0.9562034420755202,
#    0.9567394094993582,
#    0.9583333333333334,
#    0.9593194320071639,
#    0.9599590635793783,
#    0.9603783231083844,
#    0.9607165706973768],
#   'qhat': [-1.8972786724567414,
#    -1.985589406490326,
#    -2.079612076282501,
#    -2.1470189094543457,
#    -2.2259439897537234,
#    -2.3055547404289247,
#    -2.3792113399505617,
#    -2.4728984212875367,
#    -2.551487798690796,
#    -2.6205308389663697,
#    -2.6758528399467467,
#    -2.7101683664321903,
#    -2.772307971715927,
#    -2.8523643589019776,
#    -2.9493459463119507,
#    -3.036146795153618,
#    -3.1217100918293,
#    -3.2054973033815624,
#    -3.2671453881263735,
#    -3.360359891951084]},
#  160: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9014,
#    0.898,
#    0.8954,
#    0.8937,
#    0.8921,
#    0.8879,
#    0.8838,
#    0.8816,
#    0.8801,
#    0.877,
#    0.8748,
#    0.8728,
#    0.8704,
#    0.8691,
#    0.8659,
#    0.8624,
#    0.8617,
#    0.8622,
#    0.8622,
#    0.8625],
#   'efficiency': [1.1364,
#    1.1253,
#    1.1147,
#    1.1083,
#    1.1029,
#    1.0919,
#    1.0811,
#    1.0744,
#    1.0678,
#    1.0587,
#    1.0526,
#    1.0472,
#    1.0428,
#    1.0384,
#    1.0315,
#    1.0223,
#    1.0193,
#    1.0215,
#    1.0219,
#    1.0225],
#   'singleton_cov': [0.9494708994708995,
#    0.9503097403453276,
#    0.9513187245768272,
#    0.9519633507853403,
#    0.9522938178015946,
#    0.9516612377850163,
#    0.9533307261113284,
#    0.9534278652270066,
#    0.9542153047989624,
#    0.9543101216670982,
#    0.9547452805792604,
#    0.9552682611506141,
#    0.9555987055016181,
#    0.956167571761055,
#    0.9559545337122191,
#    0.955664389740946,
#    0.9562250547186816,
#    0.9561573178594455,
#    0.955664389740946,
#    0.955664389740946],
#   'qhat': [-1.8885816049575805,
#    -1.9662070226669313,
#    -2.0465987491607667,
#    -2.0983531284332275,
#    -2.14923176407814,
#    -2.2394895839691165,
#    -2.313226089477539,
#    -2.360462965965271,
#    -2.412988877296448,
#    -2.479444713592529,
#    -2.522085704803467,
#    -2.5611421537399295,
#    -2.5933479380607602,
#    -2.6286091017723083,
#    -2.681953480243683,
#    -2.7441147279739377,
#    -2.773515870627016,
#    -2.752103569507599,
#    -2.748209819793701,
#    -2.7419634574651717]},
#  180: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9015,
#    0.8989,
#    0.8956,
#    0.8931,
#    0.8921,
#    0.8893,
#    0.8862,
#    0.8831,
#    0.8807,
#    0.8782,
#    0.8762,
#    0.8746,
#    0.8712,
#    0.8688,
#    0.8675,
#    0.8648,
#    0.8644,
#    0.8628,
#    0.862,
#    0.8632],
#   'efficiency': [1.1369,
#    1.1277,
#    1.1153,
#    1.1067,
#    1.1029,
#    1.0953,
#    1.0876,
#    1.0787,
#    1.0707,
#    1.0635,
#    1.0566,
#    1.0513,
#    1.0446,
#    1.0377,
#    1.0343,
#    1.0283,
#    1.0268,
#    1.0235,
#    1.0205,
#    1.0249],
#   'singleton_cov': [0.9495965074745336,
#    0.950151655017803,
#    0.9513059456621604,
#    0.9519884877027734,
#    0.9522938178015946,
#    0.9515056707078607,
#    0.9521886399166233,
#    0.9532552083333333,
#    0.9538781343380538,
#    0.954197482807837,
#    0.9545689878332901,
#    0.9550213260953858,
#    0.9552393272962484,
#    0.956167571761055,
#    0.956095041322314,
#    0.9553778694867165,
#    0.9555297757153906,
#    0.9554066245650212,
#    0.9560736828545665,
#    0.9551488593890965],
#   'qhat': [-1.8816485214233398,
#    -1.9494049263000488,
#    -2.0436054968833925,
#    -2.1130588054656982,
#    -2.148295006752014,
#    -2.2133802556991578,
#    -2.268649423122406,
#    -2.3343526554107665,
#    -2.396060713529587,
#    -2.4428885436058043,
#    -2.4919128441810607,
#    -2.5318693161010746,
#    -2.578312985897064,
#    -2.6355609178543093,
#    -2.6609845250844955,
#    -2.707538013458252,
#    -2.715748932361603,
#    -2.7343869471549986,
#    -2.758385295122862,
#    -2.7270335280895233]},
#  200: {'lambda': [0.01,
#    0.06,
#    0.11,
#    0.16,
#    0.21,
#    0.26,
#    0.31,
#    0.36,
#    0.41,
#    0.46,
#    0.51,
#    0.56,
#    0.61,
#    0.66,
#    0.71,
#    0.76,
#    0.81,
#    0.86,
#    0.91,
#    0.96],
#   'coverage': [0.9014,
#    0.8987,
#    0.8959,
#    0.8928,
#    0.8905,
#    0.8878,
#    0.8838,
#    0.881,
#    0.8777,
#    0.8753,
#    0.8714,
#    0.8672,
#    0.8631,
#    0.8613,
#    0.8575,
#    0.8543,
#    0.8502,
#    0.8491,
#    0.8481,
#    0.8486],
#   'efficiency': [1.1364,
#    1.1275,
#    1.1161,
#    1.1049,
#    1.0988,
#    1.091,
#    1.0812,
#    1.0717,
#    1.0612,
#    1.0537,
#    1.0451,
#    1.0337,
#    1.0246,
#    1.0186,
#    1.0087,
#    1.0011,
#    0.99,
#    0.9873,
#    0.9832,
#    0.9855],
#   'singleton_cov': [0.9494708994708995,
#    0.9501385041551247,
#    0.9514116874589625,
#    0.9522813439665315,
#    0.9517034329721968,
#    0.95217617930675,
#    0.9533246414602347,
#    0.9538601507668313,
#    0.9543745949449125,
#    0.9547394284236389,
#    0.9553513653423062,
#    0.955977278595404,
#    0.9552719773137407,
#    0.9563369397217929,
#    0.9564491264131552,
#    0.9567227430332605,
#    0.9577031530376826,
#    0.958076923076923,
#    0.958407985666752,
#    0.9582265504869297],
#   'qhat': [-1.8875775885581971,
#    -1.9499384546279908,
#    -2.0395541203022005,
#    -2.128803029060364,
#    -2.186340022087097,
#    -2.247212381362915,
#    -2.3120487570762633,
#    -2.386224555969238,
#    -2.464982209205627,
#    -2.508162970542908,
#    -2.5754561185836793,
#    -2.6645889091491703,
#    -2.7294859957695006,
#    -2.7790720868110657,
#    -2.8668317091464997,
#    -2.923249191045761,
#    -3.0025155019760135,
#    -3.0287138828635216,
#    -3.0556766974925997,
#    -3.0415355681069194]}}

# %%
import pandas as pd
# save as excel

dfs = {}

for K, metrics in plot_data_clustering.items():

    filtered = {key: val for key, val in metrics.items() if key != "lambda"}


    df = pd.DataFrame(filtered)
    dfs[K] = df

output_path = "clustering_results.xlsx"

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    for K, df in dfs.items():
        df.to_excel(writer, sheet_name=f"K_{K}", index=False)

print(f"Saved Excel file to {output_path}")
# Out:
# Saved Excel file to clustering_results.xlsx

# %% [markdown]
# #### Clustering plots

# %%
plt.figure()

for K, vals in plot_data_clustering.items():
    if K == "BASELINE": 
        continue
    lambdas = np.array(vals["lambda"])
    coverage = np.array(vals["coverage"]) * 100   
    plt.plot(lambdas, coverage, marker="o", label=f"K={K}")

plt.axhline(y =0.9016*100, linestyle="--", label="Baseline (no smoothing)")
plt.xlabel("Smoothing parameter λ")
plt.ylabel("Coverage (%)")
plt.title("Cluster smoothing – Coverage vs λ")
plt.legend()
plt.grid(True)
plt.tight_layout()

# %%
print(plot_data_clustering[180]['coverage'][0])
print(plot_data_clustering[200]['coverage'][0])
print(plot_data_clustering[20]['coverage'][0])
# Out:
# 0.9015
# 0.9014
# 0.9004

# %%
plt.figure()

for K, vals in plot_data_clustering.items():
    if K == "BASELINE":  
        continue
    lambdas = np.array(vals["lambda"])
    coverage = np.array(vals["efficiency"])  
    plt.plot(lambdas, coverage, marker="o", label=f"K={K}")

plt.axhline(y =1.1376, linestyle="--", label="Baseline (no smoothing)")
plt.xlabel("Smoothing parameter λ")
plt.ylabel("Efficiency")
plt.title("Cluster smoothing – Efficiency vs λ")
plt.legend()
plt.grid(True)
plt.ylim(0.8, 1.20)
plt.tight_layout()

# %%
print(plot_data_clustering[180]['efficiency'][0])
print(plot_data_clustering[200]['efficiency'][0])
# Out:
# 1.1369
# 1.1364

# %%
K_values = np.arange(20, 201, 20)  
target_lambda = 0.11

eff_vals = []
cov_vals = []

for K in K_values:
    data = plot_data_clustering[K]
    lambdas = np.array(data["lambda"])
    efficiencies = np.array(data["efficiency"])
    coverages = np.array(data["coverage"])

    idx = (np.abs(lambdas - target_lambda)).argmin()
    
    eff_vals.append(efficiencies[idx])
    cov_vals.append(coverages[idx])

eff_vals = np.array(eff_vals)
cov_vals = np.array(cov_vals)


# Plot Coverage vs K 
plt.figure()
plt.plot(K_values, cov_vals*100, marker="o", label=f"Cluster smoothing (λ={target_lambda})")
plt.xlabel("Number of clusters K")
plt.ylabel("Coverage (%)")
plt.title(f"Cluster smoothing – Coverage vs K (λ={target_lambda})")
plt.xticks(K_values)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.axhline(y =0.9016*100, linestyle="--", label="Baseline (no smoothing)")

# Plot Efficiency vs K 
plt.figure()
plt.axhline(y =1.1376, linestyle="--", label="Baseline (no smoothing)")
plt.plot(K_values, eff_vals, marker="o", label=f"Cluster smoothing (λ={target_lambda})")
plt.xlabel("Number of clusters K")
plt.ylabel("Average set size (efficiency)")
plt.title(f"Cluster smoothing – Efficiency vs K (λ={target_lambda})")
plt.xticks(K_values)
plt.legend()
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# ### 6.2 kNN

# %%
folder = "code/examples/scratch/rhti/conformal"
alpha = 0.1
target_cov = 1.0 - alpha

holdout = torch.load(folder + "/holdout_predictions.pth", weights_only=False)
val = torch.load(folder + "/val_predictions.pth", weights_only=False)
test = torch.load(folder + "/test_predictions.pth", weights_only=False)
feats = np.load(folder + "/holdout_features.npz")["features"]

cal_labels = holdout["labels"]
cal_outputs = holdout["outputs"]
n_cal = len(cal_labels)
cal_scores = 1.0 - cal_outputs[np.arange(n_cal), cal_labels]

data = {
    "cal_scores": cal_scores,
    "cal_feats": feats,
    "val_labels": val["labels"],
    "val_outputs": val["outputs"],
    "test_labels": test["labels"],
    "test_outputs": test["outputs"],
}

# %%
# kNN sweep

knn_results_global = []

print("Calibration Results (k-NN)")

baseline_metrics = evaluate_and_return_metrics(qhat_base, data["val_outputs"], data["val_labels"], "Baseline CAL: ")

ks = list(range(2, 22, 2)) #[2, 8, 14]
lambdas = [i * 0.05 for i in range(0, 21)] #[0.01, 0.025, 0.05, 0.1]

for k in ks:
    print(f"kNN k={k}")
    nbrs = NearestNeighbors(n_neighbors=k, metric="euclidean", n_jobs=-1)
    nbrs.fit(data["cal_feats"])
    _, indices = nbrs.kneighbors(data["cal_feats"])

    neighbor_means = data["cal_scores"][indices].mean(axis=1)

    for lam in lambdas:
        smooth_scores = (1.0 - lam) * data["cal_scores"] + lam * neighbor_means
        qhat = compute_qhat(smooth_scores, alpha)
        
        metrics = evaluate_and_return_metrics(qhat, data["val_outputs"], data["val_labels"], "CAL: ")

        config_name = f"k={k}, lambda={lam}"
        knn_results_global.append((config_name, metrics))
        
        print(f"    lambda={lam:}: {metrics['result_str']}")
# Out:
# Calibration Results (k-NN)
# kNN k=2
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.02047%
#     lambda=0.1: CAL: Coverage: 89.87%, Eff: 1.13, Single: 95.01451%
#     lambda=0.15000000000000002: CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.03490%
#     lambda=0.2: CAL: Coverage: 89.75%, Eff: 1.12, Single: 95.04546%
#     lambda=0.25: CAL: Coverage: 89.70%, Eff: 1.12, Single: 95.03490%
#     lambda=0.30000000000000004: CAL: Coverage: 89.61%, Eff: 1.12, Single: 95.12740%
#     lambda=0.35000000000000003: CAL: Coverage: 89.56%, Eff: 1.12, Single: 95.13123%
#     lambda=0.4: CAL: Coverage: 89.59%, Eff: 1.12, Single: 95.14053%
#     lambda=0.45: CAL: Coverage: 89.57%, Eff: 1.12, Single: 95.14117%
#     lambda=0.5: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16573%
#     lambda=0.55: CAL: Coverage: 89.41%, Eff: 1.11, Single: 95.15707%
#     lambda=0.6000000000000001: CAL: Coverage: 89.35%, Eff: 1.11, Single: 95.20880%
#     lambda=0.65: CAL: Coverage: 89.25%, Eff: 1.10, Single: 95.21694%
#     lambda=0.7000000000000001: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%
#     lambda=0.75: CAL: Coverage: 89.11%, Eff: 1.10, Single: 95.19520%
#     lambda=0.8: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%
#     lambda=0.8500000000000001: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.16971%
#     lambda=0.9: CAL: Coverage: 89.02%, Eff: 1.10, Single: 95.17349%
#     lambda=0.9500000000000001: CAL: Coverage: 88.91%, Eff: 1.10, Single: 95.14930%
#     lambda=1.0: CAL: Coverage: 88.83%, Eff: 1.09, Single: 95.16801%
# kNN k=4
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 90.03%, Eff: 1.13, Single: 94.99009%
#     lambda=0.1: CAL: Coverage: 89.85%, Eff: 1.13, Single: 95.03097%
#     lambda=0.15000000000000002: CAL: Coverage: 89.66%, Eff: 1.12, Single: 95.05393%
#     lambda=0.2: CAL: Coverage: 89.60%, Eff: 1.12, Single: 95.12740%
#     lambda=0.25: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16573%
#     lambda=0.30000000000000004: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.19885%
#     lambda=0.35000000000000003: CAL: Coverage: 89.16%, Eff: 1.10, Single: 95.23001%
#     lambda=0.4: CAL: Coverage: 88.94%, Eff: 1.10, Single: 95.14993%
#     lambda=0.45: CAL: Coverage: 88.78%, Eff: 1.09, Single: 95.21762%
#     lambda=0.5: CAL: Coverage: 88.62%, Eff: 1.09, Single: 95.22198%
#     lambda=0.55: CAL: Coverage: 88.49%, Eff: 1.08, Single: 95.28400%
#     lambda=0.6000000000000001: CAL: Coverage: 88.34%, Eff: 1.08, Single: 95.33550%
#     lambda=0.65: CAL: Coverage: 88.18%, Eff: 1.08, Single: 95.33976%
#     lambda=0.7000000000000001: CAL: Coverage: 88.06%, Eff: 1.07, Single: 95.38901%
#     lambda=0.75: CAL: Coverage: 87.96%, Eff: 1.07, Single: 95.43154%
#     lambda=0.8: CAL: Coverage: 87.82%, Eff: 1.06, Single: 95.41975%
#     lambda=0.8500000000000001: CAL: Coverage: 87.73%, Eff: 1.06, Single: 95.45396%
#     lambda=0.9: CAL: Coverage: 87.68%, Eff: 1.06, Single: 95.44278%
#     lambda=0.9500000000000001: CAL: Coverage: 87.49%, Eff: 1.05, Single: 95.47394%
#     lambda=1.0: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.48804%
# kNN k=6
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01718%
#     lambda=0.1: CAL: Coverage: 89.85%, Eff: 1.13, Single: 95.03097%
#     lambda=0.15000000000000002: CAL: Coverage: 89.64%, Eff: 1.12, Single: 95.05523%
#     lambda=0.2: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16383%
#     lambda=0.25: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.20136%
#     lambda=0.30000000000000004: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%
#     lambda=0.35000000000000003: CAL: Coverage: 88.99%, Eff: 1.10, Single: 95.16045%
#     lambda=0.4: CAL: Coverage: 88.83%, Eff: 1.09, Single: 95.16801%
#     lambda=0.45: CAL: Coverage: 88.54%, Eff: 1.08, Single: 95.28339%
#     lambda=0.5: CAL: Coverage: 88.30%, Eff: 1.08, Single: 95.32552%
#     lambda=0.55: CAL: Coverage: 88.13%, Eff: 1.07, Single: 95.34279%
#     lambda=0.6000000000000001: CAL: Coverage: 88.01%, Eff: 1.07, Single: 95.42153%
#     lambda=0.65: CAL: Coverage: 87.78%, Eff: 1.06, Single: 95.44865%
#     lambda=0.7000000000000001: CAL: Coverage: 87.49%, Eff: 1.05, Single: 95.47394%
#     lambda=0.75: CAL: Coverage: 87.42%, Eff: 1.05, Single: 95.51564%
#     lambda=0.8: CAL: Coverage: 87.31%, Eff: 1.05, Single: 95.51506%
#     lambda=0.8500000000000001: CAL: Coverage: 87.04%, Eff: 1.04, Single: 95.55987%
#     lambda=0.9: CAL: Coverage: 86.94%, Eff: 1.04, Single: 95.61619%
#     lambda=0.9500000000000001: CAL: Coverage: 86.88%, Eff: 1.04, Single: 95.62969%
#     lambda=1.0: CAL: Coverage: 86.80%, Eff: 1.04, Single: 95.63307%
# kNN k=8
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01982%
#     lambda=0.1: CAL: Coverage: 89.78%, Eff: 1.12, Single: 95.03163%
#     lambda=0.15000000000000002: CAL: Coverage: 89.61%, Eff: 1.12, Single: 95.08864%
#     lambda=0.2: CAL: Coverage: 89.46%, Eff: 1.11, Single: 95.13761%
#     lambda=0.25: CAL: Coverage: 89.30%, Eff: 1.11, Single: 95.21631%
#     lambda=0.30000000000000004: CAL: Coverage: 89.02%, Eff: 1.10, Single: 95.17349%
#     lambda=0.35000000000000003: CAL: Coverage: 88.85%, Eff: 1.09, Single: 95.15562%
#     lambda=0.4: CAL: Coverage: 88.61%, Eff: 1.09, Single: 95.22135%
#     lambda=0.45: CAL: Coverage: 88.38%, Eff: 1.08, Single: 95.33611%
#     lambda=0.5: CAL: Coverage: 88.20%, Eff: 1.08, Single: 95.32552%
#     lambda=0.55: CAL: Coverage: 88.12%, Eff: 1.07, Single: 95.36002%
#     lambda=0.6000000000000001: CAL: Coverage: 87.92%, Eff: 1.07, Single: 95.45632%
#     lambda=0.65: CAL: Coverage: 87.64%, Eff: 1.06, Single: 95.45690%
#     lambda=0.7000000000000001: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.50097%
#     lambda=0.75: CAL: Coverage: 87.20%, Eff: 1.05, Single: 95.52509%
#     lambda=0.8: CAL: Coverage: 86.92%, Eff: 1.04, Single: 95.61676%
#     lambda=0.8500000000000001: CAL: Coverage: 86.80%, Eff: 1.04, Single: 95.62016%
#     lambda=0.9: CAL: Coverage: 86.53%, Eff: 1.03, Single: 95.56072%
#     lambda=0.9500000000000001: CAL: Coverage: 86.45%, Eff: 1.03, Single: 95.55355%
#     lambda=1.0: CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.61799%
# kNN k=10
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 90.03%, Eff: 1.13, Single: 95.00330%
#     lambda=0.1: CAL: Coverage: 89.76%, Eff: 1.12, Single: 95.04415%
#     lambda=0.15000000000000002: CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13315%
#     lambda=0.2: CAL: Coverage: 89.35%, Eff: 1.11, Single: 95.22439%
#     lambda=0.25: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.20136%
#     lambda=0.30000000000000004: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.17034%
#     lambda=0.35000000000000003: CAL: Coverage: 88.71%, Eff: 1.09, Single: 95.22135%
#     lambda=0.4: CAL: Coverage: 88.46%, Eff: 1.08, Single: 95.28462%
#     lambda=0.45: CAL: Coverage: 88.18%, Eff: 1.08, Single: 95.32674%
#     lambda=0.5: CAL: Coverage: 88.07%, Eff: 1.07, Single: 95.38781%
#     lambda=0.55: CAL: Coverage: 87.83%, Eff: 1.06, Single: 95.43094%
#     lambda=0.6000000000000001: CAL: Coverage: 87.69%, Eff: 1.06, Single: 95.45513%
#     lambda=0.65: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.48804%
#     lambda=0.7000000000000001: CAL: Coverage: 87.21%, Eff: 1.05, Single: 95.52567%
#     lambda=0.75: CAL: Coverage: 86.95%, Eff: 1.04, Single: 95.61562%
#     lambda=0.8: CAL: Coverage: 86.75%, Eff: 1.03, Single: 95.61120%
#     lambda=0.8500000000000001: CAL: Coverage: 86.49%, Eff: 1.03, Single: 95.53664%
#     lambda=0.9: CAL: Coverage: 86.39%, Eff: 1.03, Single: 95.54009%
#     lambda=0.9500000000000001: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.62081%
#     lambda=1.0: CAL: Coverage: 86.08%, Eff: 1.02, Single: 95.65217%
# kNN k=12
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01982%
#     lambda=0.1: CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.03359%
#     lambda=0.15000000000000002: CAL: Coverage: 89.57%, Eff: 1.12, Single: 95.14117%
#     lambda=0.2: CAL: Coverage: 89.38%, Eff: 1.11, Single: 95.15707%
#     lambda=0.25: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.20324%
#     lambda=0.30000000000000004: CAL: Coverage: 89.06%, Eff: 1.10, Single: 95.17034%
#     lambda=0.35000000000000003: CAL: Coverage: 88.72%, Eff: 1.09, Single: 95.20833%
#     lambda=0.4: CAL: Coverage: 88.46%, Eff: 1.08, Single: 95.28462%
#     lambda=0.45: CAL: Coverage: 88.15%, Eff: 1.07, Single: 95.34279%
#     lambda=0.5: CAL: Coverage: 88.02%, Eff: 1.07, Single: 95.42094%
#     lambda=0.55: CAL: Coverage: 87.75%, Eff: 1.06, Single: 95.43923%
#     lambda=0.6000000000000001: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.50039%
#     lambda=0.65: CAL: Coverage: 87.19%, Eff: 1.05, Single: 95.53687%
#     lambda=0.7000000000000001: CAL: Coverage: 86.94%, Eff: 1.04, Single: 95.62912%
#     lambda=0.75: CAL: Coverage: 86.79%, Eff: 1.03, Single: 95.63420%
#     lambda=0.8: CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.56014%
#     lambda=0.8500000000000001: CAL: Coverage: 86.24%, Eff: 1.02, Single: 95.56644%
#     lambda=0.9: CAL: Coverage: 86.22%, Eff: 1.02, Single: 95.61799%
#     lambda=0.9500000000000001: CAL: Coverage: 85.99%, Eff: 1.01, Single: 95.62757%
#     lambda=1.0: CAL: Coverage: 85.87%, Eff: 1.01, Single: 95.61922%
# kNN k=14
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01982%
#     lambda=0.1: CAL: Coverage: 89.71%, Eff: 1.12, Single: 95.03490%
#     lambda=0.15000000000000002: CAL: Coverage: 89.52%, Eff: 1.11, Single: 95.12003%
#     lambda=0.2: CAL: Coverage: 89.35%, Eff: 1.11, Single: 95.20817%
#     lambda=0.25: CAL: Coverage: 89.26%, Eff: 1.10, Single: 95.20324%
#     lambda=0.30000000000000004: CAL: Coverage: 89.06%, Eff: 1.10, Single: 95.17034%
#     lambda=0.35000000000000003: CAL: Coverage: 88.78%, Eff: 1.09, Single: 95.19281%
#     lambda=0.4: CAL: Coverage: 88.43%, Eff: 1.08, Single: 95.32187%
#     lambda=0.45: CAL: Coverage: 88.15%, Eff: 1.07, Single: 95.34218%
#     lambda=0.5: CAL: Coverage: 87.86%, Eff: 1.07, Single: 95.42976%
#     lambda=0.55: CAL: Coverage: 87.70%, Eff: 1.06, Single: 95.43101%
#     lambda=0.6000000000000001: CAL: Coverage: 87.33%, Eff: 1.05, Single: 95.51506%
#     lambda=0.65: CAL: Coverage: 87.11%, Eff: 1.04, Single: 95.52393%
#     lambda=0.7000000000000001: CAL: Coverage: 86.83%, Eff: 1.04, Single: 95.61732%
#     lambda=0.75: CAL: Coverage: 86.60%, Eff: 1.03, Single: 95.60780%
#     lambda=0.8: CAL: Coverage: 86.28%, Eff: 1.02, Single: 95.52835%
#     lambda=0.8500000000000001: CAL: Coverage: 86.18%, Eff: 1.02, Single: 95.63313%
#     lambda=0.9: CAL: Coverage: 85.98%, Eff: 1.01, Single: 95.64043%
#     lambda=0.9500000000000001: CAL: Coverage: 85.87%, Eff: 1.01, Single: 95.61922%
#     lambda=1.0: CAL: Coverage: 85.77%, Eff: 1.01, Single: 95.63150%
# kNN k=16
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01916%
#     lambda=0.1: CAL: Coverage: 89.72%, Eff: 1.12, Single: 95.03359%
#     lambda=0.15000000000000002: CAL: Coverage: 89.54%, Eff: 1.11, Single: 95.13315%
#     lambda=0.2: CAL: Coverage: 89.38%, Eff: 1.11, Single: 95.15707%
#     lambda=0.25: CAL: Coverage: 89.25%, Eff: 1.10, Single: 95.21756%
#     lambda=0.30000000000000004: CAL: Coverage: 88.99%, Eff: 1.10, Single: 95.15982%
#     lambda=0.35000000000000003: CAL: Coverage: 88.71%, Eff: 1.09, Single: 95.22135%
#     lambda=0.4: CAL: Coverage: 88.33%, Eff: 1.08, Single: 95.32430%
#     lambda=0.45: CAL: Coverage: 88.10%, Eff: 1.07, Single: 95.38661%
#     lambda=0.5: CAL: Coverage: 87.76%, Eff: 1.06, Single: 95.42568%
#     lambda=0.55: CAL: Coverage: 87.52%, Eff: 1.05, Single: 95.46277%
#     lambda=0.6000000000000001: CAL: Coverage: 87.14%, Eff: 1.05, Single: 95.53514%
#     lambda=0.65: CAL: Coverage: 86.95%, Eff: 1.04, Single: 95.61562%
#     lambda=0.7000000000000001: CAL: Coverage: 86.82%, Eff: 1.04, Single: 95.61789%
#     lambda=0.75: CAL: Coverage: 86.53%, Eff: 1.03, Single: 95.56072%
#     lambda=0.8: CAL: Coverage: 86.25%, Eff: 1.02, Single: 95.55412%
#     lambda=0.8500000000000001: CAL: Coverage: 86.12%, Eff: 1.02, Single: 95.64826%
#     lambda=0.9: CAL: Coverage: 85.93%, Eff: 1.01, Single: 95.62926%
#     lambda=0.9500000000000001: CAL: Coverage: 85.87%, Eff: 1.01, Single: 95.63207%
#     lambda=1.0: CAL: Coverage: 85.65%, Eff: 1.01, Single: 95.64659%
# kNN k=18
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.01916%
#     lambda=0.1: CAL: Coverage: 89.66%, Eff: 1.12, Single: 95.05328%
#     lambda=0.15000000000000002: CAL: Coverage: 89.46%, Eff: 1.11, Single: 95.16383%
#     lambda=0.2: CAL: Coverage: 89.31%, Eff: 1.11, Single: 95.19885%
#     lambda=0.25: CAL: Coverage: 89.13%, Eff: 1.10, Single: 95.21756%
#     lambda=0.30000000000000004: CAL: Coverage: 88.85%, Eff: 1.09, Single: 95.15562%
#     lambda=0.35000000000000003: CAL: Coverage: 88.60%, Eff: 1.09, Single: 95.23375%
#     lambda=0.4: CAL: Coverage: 88.31%, Eff: 1.08, Single: 95.32552%
#     lambda=0.45: CAL: Coverage: 88.04%, Eff: 1.07, Single: 95.40558%
#     lambda=0.5: CAL: Coverage: 87.79%, Eff: 1.06, Single: 95.44865%
#     lambda=0.55: CAL: Coverage: 87.52%, Eff: 1.05, Single: 95.46277%
#     lambda=0.6000000000000001: CAL: Coverage: 87.15%, Eff: 1.05, Single: 95.53514%
#     lambda=0.65: CAL: Coverage: 86.93%, Eff: 1.04, Single: 95.62856%
#     lambda=0.7000000000000001: CAL: Coverage: 86.70%, Eff: 1.03, Single: 95.60894%
#     lambda=0.75: CAL: Coverage: 86.51%, Eff: 1.03, Single: 95.56014%
#     lambda=0.8: CAL: Coverage: 86.23%, Eff: 1.02, Single: 95.56587%
#     lambda=0.8500000000000001: CAL: Coverage: 86.08%, Eff: 1.02, Single: 95.65161%
#     lambda=0.9: CAL: Coverage: 85.87%, Eff: 1.01, Single: 95.63207%
#     lambda=0.9500000000000001: CAL: Coverage: 85.77%, Eff: 1.01, Single: 95.63150%
#     lambda=1.0: CAL: Coverage: 85.59%, Eff: 1.00, Single: 95.69741%
# kNN k=20
#     lambda=0.0: CAL: Coverage: 90.16%, Eff: 1.14, Single: 94.96955%
#     lambda=0.05: CAL: Coverage: 89.99%, Eff: 1.13, Single: 95.02113%
#     lambda=0.1: CAL: Coverage: 89.68%, Eff: 1.12, Single: 95.03686%
#     lambda=0.15000000000000002: CAL: Coverage: 89.44%, Eff: 1.11, Single: 95.16573%
#     lambda=0.2: CAL: Coverage: 89.28%, Eff: 1.10, Single: 95.22813%
#     lambda=0.25: CAL: Coverage: 89.08%, Eff: 1.10, Single: 95.16971%
#     lambda=0.30000000000000004: CAL: Coverage: 88.84%, Eff: 1.09, Single: 95.16864%
#     lambda=0.35000000000000003: CAL: Coverage: 88.49%, Eff: 1.08, Single: 95.28216%
#     lambda=0.4: CAL: Coverage: 88.21%, Eff: 1.08, Single: 95.31311%
#     lambda=0.45: CAL: Coverage: 87.95%, Eff: 1.07, Single: 95.44333%
#     lambda=0.5: CAL: Coverage: 87.72%, Eff: 1.06, Single: 95.44219%
#     lambda=0.55: CAL: Coverage: 87.46%, Eff: 1.05, Single: 95.47570%
#     lambda=0.6000000000000001: CAL: Coverage: 87.12%, Eff: 1.04, Single: 95.52393%
#     lambda=0.65: CAL: Coverage: 86.94%, Eff: 1.04, Single: 95.61619%
#     lambda=0.7000000000000001: CAL: Coverage: 86.61%, Eff: 1.03, Single: 95.62016%
#     lambda=0.75: CAL: Coverage: 86.23%, Eff: 1.02, Single: 95.56587%
#     lambda=0.8: CAL: Coverage: 86.13%, Eff: 1.02, Single: 95.64657%
#     lambda=0.8500000000000001: CAL: Coverage: 85.92%, Eff: 1.01, Single: 95.64323%
#     lambda=0.9: CAL: Coverage: 85.65%, Eff: 1.01, Single: 95.64659%
#     lambda=0.9500000000000001: CAL: Coverage: 85.55%, Eff: 1.00, Single: 95.69575%
#     lambda=1.0: CAL: Coverage: 85.42%, Eff: 1.00, Single: 95.68401%

# %% [markdown]
# #### knn Plots

# %%
plot_data_kNN = {}  

for label, metrics in knn_results_global:
    if label == "BASELINE":
        K = "BASELINE"
        lam = None
    else:
        match = re.match(r"k=(\d+), lambda=([0-9.]+)", label)
        if match:
            K = int(match.group(1))
            lam = float(match.group(2))
        else:
            continue

    if K not in plot_data_kNN:
        plot_data_kNN[K] = {"lambda": [], "coverage": [], "efficiency": [],
                        "singleton_cov": [], "qhat": []}

    plot_data_kNN[K]["lambda"].append(lam)
    plot_data_kNN[K]["coverage"].append(float(metrics["coverage"]))
    plot_data_kNN[K]["efficiency"].append(float(metrics["efficiency"]))
    plot_data_kNN[K]["singleton_cov"].append(float(metrics["singleton_cov"]))
    plot_data_kNN[K]["qhat"].append(float(metrics["qhat"]))
    
plt.figure()

for K, vals in plot_data_kNN.items():
    lambdas = np.array(vals["lambda"])
    coverage = np.array(vals["coverage"]) * 100   
    plt.plot(lambdas, coverage, marker="o", label=f"K={K}")

plt.axhline(y =0.9016*100, linestyle="--", label="Baseline (no smoothing)")
plt.xlabel("Smoothing parameter λ")
plt.ylabel("Coverage (%)")
plt.title("kNN smoothing – Coverage vs λ")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.figure()



for K, vals in plot_data_kNN.items():
    lambdas = np.array(vals["lambda"])
    efficiency = np.array(vals["efficiency"]) 
    plt.plot(lambdas, efficiency, marker="o", label=f"K={K}")

plt.axhline(y =1.1376, linestyle="--", label="Baseline (no smoothing)")
plt.xlabel("Smoothing parameter λ")
plt.ylabel("Efficiency")
plt.title("kNN smoothing – Efficiency vs λ")
plt.legend()
plt.grid(True)
plt.tight_layout()

# %%
# save to excel
dfs = {}

for K, metrics in plot_data_kNN.items():
    filtered = {key: val for key, val in metrics.items() if key != "lambda"}

    df = pd.DataFrame(filtered)
    dfs[K] = df


output_path = "kNN_results.xlsx"

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    for K, df in dfs.items():
        df.to_excel(writer, sheet_name=f"K_{K}", index=False)

print(f"Saved Excel file to {output_path}")
# Out:
# Saved Excel file to kNN_results.xlsx

# %%
K_values = np.arange(2, 22, 2)  
target_lambda = 0.15

eff_vals = []
cov_vals = []

for K in K_values:
    data = plot_data_kNN[K]
    lambdas = np.array(data["lambda"])
    efficiencies = np.array(data["efficiency"])
    coverages = np.array(data["coverage"])
    
    # Find the index closest to target_lambda
    idx = (np.abs(lambdas - target_lambda)).argmin()
    
    eff_vals.append(efficiencies[idx])
    cov_vals.append(coverages[idx])

eff_vals = np.array(eff_vals)
cov_vals = np.array(cov_vals)


# Plot Coverage vs K 
plt.figure()
plt.plot(K_values, cov_vals*100, marker="o", label=f"kNN smoothing (λ={target_lambda})")
plt.xlabel("Number of clusters K")
plt.ylabel("Coverage (%)")
plt.title(f"kNN smoothing – Coverage vs K (λ={target_lambda})")
plt.xticks(K_values)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.axhline(y =0.9016*100, linestyle="--", label="Baseline (no smoothing)")

# Plot Efficiency vs K
plt.figure()
plt.axhline(y =1.1376, linestyle="--", label="Baseline (no smoothing)")
plt.plot(K_values, eff_vals, marker="o", label=f"kNN smoothing (λ={target_lambda})")
plt.xlabel("Number of clusters K")
plt.ylabel("Average set size (efficiency)")
plt.title(f"kNN smoothing – Efficiency vs K (λ={target_lambda})")
plt.xticks(K_values)
plt.legend()
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# ## 7.Testing Results

# %% [markdown]
# Based on the output above, we identified the best parameters: K = 110 and λ = 0.02 for clustering, and k = 8 and λ = 0.025 for k-NN. We will use these parameters for testing data:

# %%
folder = "code/examples/scratch/rhti/conformal"
alpha = 0.1
target_cov = 1.0 - alpha

holdout = torch.load(folder + "/holdout_predictions.pth", weights_only=False)
val = torch.load(folder + "/val_predictions.pth", weights_only=False)
test = torch.load(folder + "/test_predictions.pth", weights_only=False)
feats = np.load(folder + "/holdout_features.npz")["features"]

cal_labels = holdout["labels"]
cal_outputs = holdout["outputs"]
n_cal = len(cal_labels)
cal_scores = 1.0 - cal_outputs[np.arange(n_cal), cal_labels]

data = {
    "cal_scores": cal_scores,
    "cal_feats": feats,
    "val_labels": val["labels"],
    "val_outputs": val["outputs"],
    "test_labels": test["labels"],
    "test_outputs": test["outputs"],
}

# %%
def find_qhat_by_config(results_list, target_config_name):
    for name, metrics in results_list:
        if name == target_config_name:
            return name, metrics["qhat"]
    return "Fallback (Baseline Qhat)", qhat_base 

target_clust_name = "K=80, lambda=0.11"
best_clust_name, best_clust_qhat = find_qhat_by_config(clustering_results_global[1:], target_clust_name)

target_knn_name = "k=10, lambda=0.15000000000000002"
best_knn_name, best_knn_qhat = find_qhat_by_config(knn_results_global, target_knn_name)


final_test_results = []
test_outputs = data["test_outputs"]
test_labels = data["test_labels"]

baseline_test_metrics = evaluate_and_return_metrics(qhat_base, test_outputs, test_labels, "Baseline TEST: ")
final_test_results.append(("BASELINE", baseline_test_metrics))


clust_test_metrics = evaluate_and_return_metrics(best_clust_qhat, test_outputs, test_labels, f"{best_clust_name} TEST: ")
final_test_results.append((best_clust_name, clust_test_metrics))

knn_test_metrics = evaluate_and_return_metrics(best_knn_qhat, test_outputs, test_labels, f"{best_knn_name} TEST: ")
final_test_results.append((best_knn_name, knn_test_metrics))


print("Test Evaluation (Using Best Parameters)")

for config, result in final_test_results:
    print(f"\n--- {config} ---")
    print(result["result_str"])

print("\n")
# Out:
# Test Evaluation (Using Best Parameters)
#
# --- BASELINE ---
# Baseline TEST: Coverage: 89.78%, Eff: 1.14, Single: 94.31087%
#
# --- K=80, lambda=0.11 ---
# K=80, lambda=0.11 TEST: Coverage: 89.09%, Eff: 1.11, Single: 94.49637%
#
# --- k=10, lambda=0.15000000000000002 ---
# k=10, lambda=0.15000000000000002 TEST: Coverage: 89.16%, Eff: 1.11, Single: 94.45742%

# %% [markdown]
# ## 8. Summary
# - Baseline coverage is ~90% with an efficiency of ~1.14.
# - Cluster smoothing performs best at K = 80 and λ = 0.11, as this maintain the coverage near 90% while still achieving a lower efficiency (1.14 -> 1.11).
# - k-NN performs best at k = 10 and λ = 0.15, as this maintain the coverage near 90% while still achieving a lower efficiency (1.14 -> 1.11).
# - These optimal parameters yield a coverage of 89.09% and 89.16% for clustering and k-NN, respectively.
#
# The notebook contains the full reproducible pipeline.
